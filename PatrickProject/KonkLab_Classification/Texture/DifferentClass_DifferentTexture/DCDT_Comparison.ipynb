# %% [markdown]
# # Different Class Different Texture (DCDT) Comparison
#
# This notebook compares CVCL and CLIP models on prototype evaluation where distractors differ in class AND texture.
# For example, testing a rough apple against smooth car, shiny ball, matte book.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------------------------ -------- 10.0/12.8 MB 68.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 79.9 MB/s  0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os
import sys
import random
import torch
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from collections import defaultdict

# Path setup
REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir, os.pardir, os.pardir))

# Add discover-hidden-visual-concepts to path
DISCOVER_ROOT = os.path.join(REPO_ROOT, 'discover-hidden-visual-concepts')
sys.path.insert(0, DISCOVER_ROOT)
sys.path.insert(0, REPO_ROOT)

# Import from discover-hidden-visual-concepts repo
sys.path.append(os.path.join(DISCOVER_ROOT, 'src'))
from utils.model_loader import load_model
from models.feature_extractor import FeatureExtractor
from models.multimodal.multimodal_lit import MultiModalLitModel

# hard-coded paths
CSV_PATH = os.path.join(REPO_ROOT, 'data', 'KonkLab', 'testdata.csv')
IMG_DIR = os.path.join(REPO_ROOT, 'data', 'KonkLab', '17-objects')
MASTER_CSV = os.path.join(REPO_ROOT, 'PatrickProject', 'Chart_Generation', 'all_prototype_results.csv')
# Out:
# c:\Users\jbats\miniconda3\envs\ntu-synthetic\lib\site-packages\clip\clip.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import packaging

# %%
# Shared Dataset and Helper Functions
class TextureImageDataset(Dataset):
    """Dataset returning (img_tensor, class, texture, idx)."""
    def __init__(self, csv_path, img_dir, transform):
        self.df = pd.read_csv(csv_path)
        required = ['Filename','Class','Texture']
        assert all(c in self.df for c in required), f"CSV must contain columns: {required}"
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        cls, tex = row['Class'], row['Texture']
        fn = row['Filename']
        path = os.path.join(self.img_dir, cls, fn)
        img = Image.open(path).convert('RGB')
        return self.transform(img), cls, tex, idx

def collate_fn(batch):
    imgs = torch.stack([b[0] for b in batch])
    classes = [b[1] for b in batch]
    textures = [b[2] for b in batch]
    idxs = [b[3] for b in batch]
    return imgs, classes, textures, idxs

def run_dcdt_test(model_name, seed=0, device='cuda' if torch.cuda.is_available() else 'cpu', batch_size=64, trials_per_tuple=10, max_images=None):
    """Run Different Class Different Texture (DCDT) evaluation.
    
    Tests if model can identify objects when distractors differ in BOTH attributes:
    - Different class
    - Different texture
    
    This should be an easier test as distractors are quite different from the query.
    Example: rough apple vs. smooth car, shiny ball, matte book
    """
    random.seed(seed)
    torch.manual_seed(seed)

    # 1) load model & transform
    model, transform = load_model(model_name, seed=seed, device=device)
    extractor = FeatureExtractor(model_name, model, device)
    print(f"[INFO] Loaded model '{model_name}'")

    # 2) prepare DataLoader & extract embeddings
    ds = TextureImageDataset(CSV_PATH, IMG_DIR, transform)
    loader = DataLoader(ds, batch_size=batch_size, shuffle=False, num_workers=0, collate_fn=collate_fn)

    all_embs, all_classes, all_textures, all_idxs = [], [], [], []
    with torch.no_grad():
        for imgs, classes, textures, idxs in loader:
            feats = extractor.get_img_feature(imgs.to(device))
            feats = extractor.norm_features(feats).cpu()
            feats = feats.float()
            all_embs.append(feats)
            all_classes.extend(classes)
            all_textures.extend(textures)
            all_idxs.extend(idxs)
    all_embs = torch.cat(all_embs, dim=0)
    print(f"[INFO] Extracted embeddings for {len(all_idxs)} images")

    # 3) group by (class, texture) pair
    ct_idxs = defaultdict(lambda: defaultdict(list))
    for idx, cls, tex in zip(all_idxs, all_classes, all_textures):
        ct_idxs[cls][tex].append(idx)

    # 4) run evaluation
    total_correct = 0
    total_trials = 0
    tuple_results = {}
    
    print("[INFO] Running 4-way trials: distractors with different class AND different texture")
    for cls, tex_groups in ct_idxs.items():
        for tex, idx_list in tex_groups.items():
            # Get pool: different class AND different texture
            pool = [i for i, c, t in zip(all_idxs, all_classes, all_textures)
                    if c != cls and t != tex]
            
            if len(idx_list) < 1 or len(pool) < 3:
                continue

            correct = 0
            for _ in range(trials_per_tuple):
                q = random.choice(idx_list)
                same_rest = [i for i in idx_list if i != q]
                if same_rest:
                    proto = all_embs[[all_idxs.index(i) for i in same_rest]].mean(0)
                else:
                    proto = all_embs[all_idxs.index(q)]
                proto = proto / proto.norm()

                distractors = random.sample(pool, 3)
                candidates = [q] + distractors
                feats_cand = all_embs[[all_idxs.index(i) for i in candidates]]
                sims = feats_cand @ proto
                guess = candidates[sims.argmax().item()]

                correct += int(guess == q)
                total_correct += int(guess == q)
                total_trials += 1

            acc = correct / trials_per_tuple
            key = f"{cls}-{tex}"
            tuple_results[key] = {'correct': correct, 'trials': trials_per_tuple, 'accuracy': acc}
            print(f"{cls:12s} / {tex:10s} : {correct}/{trials_per_tuple} ({acc:.1%})")

    overall_acc = total_correct / total_trials if total_trials else 0.0
    print(f"\n[OK] Overall accuracy: {total_correct}/{total_trials} ({overall_acc:.1%})")
    
    # 5) save results
    summary_df = pd.DataFrame([{'Model': model_name, 'Test': 'Different-Class-Different-Texture', 'Correct': total_correct, 'Trials': total_trials, 'Accuracy': overall_acc}])
    
    os.makedirs(os.path.dirname(MASTER_CSV), exist_ok=True)
    if os.path.exists(MASTER_CSV):
        summary_df.to_csv(MASTER_CSV, mode='a', header=False, index=False, float_format='%.4f')
    else:
        summary_df.to_csv(MASTER_CSV, index=False, float_format='%.4f')

    return tuple_results, overall_acc

# %% [markdown]
# ## CVCL Test

# %%
# Run CVCL evaluation
cvcl_results, cvcl_overall = run_dcdt_test('cvcl-resnext')

print("\nCVCL Results by Class-Texture:")
for key, res in cvcl_results.items():
    print(f"{key:25s}: {res['correct']}/{res['trials']} ({res['accuracy']:.1%})")
print(f"\nCVCL Overall Accuracy: {cvcl_overall:.1%}")
# Out:
# Loading checkpoint from C:\Users\jbats\.cache\huggingface\hub\models--wkvong--cvcl_s_dino_resnext50_embedding\snapshots\f50eaa0c50a6076a5190b1dd52aeeb6c3e747045\cvcl_s_dino_resnext50_embedding.ckpt
# Lightning automatically upgraded your loaded checkpoint from v1.5.8 to v2.5.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\jbats\.cache\huggingface\hub\models--wkvong--cvcl_s_dino_resnext50_embedding\snapshots\f50eaa0c50a6076a5190b1dd52aeeb6c3e747045\cvcl_s_dino_resnext50_embedding.ckpt`
# [INFO] Loaded model 'cvcl-resnext'
# [INFO] Extracted embeddings for 1005 images
# [INFO] Running 4-way trials: distractors with different class AND different texture
# butterfly    / textured   : 10/10 (100.0%)
# muffins      / textured   : 10/10 (100.0%)
# pitcher      / textured   : 9/10 (90.0%)
# pitcher      / smooth     : 9/10 (90.0%)
# tennisracquet / textured   : 10/10 (100.0%)
# phone        / textured   : 8/10 (80.0%)
# headband     / textured   : 6/10 (60.0%)
# headband     / smooth     : 8/10 (80.0%)
# bagel        / textured   : 10/10 (100.0%)
# grill        / smooth     : 9/10 (90.0%)
# grill        / textured   : 7/10 (70.0%)
# basket       / textured   : 10/10 (100.0%)
# bell         / smooth     : 8/10 (80.0%)
# bell         / textured   : 10/10 (100.0%)
# sodacan      / smooth     : 10/10 (100.0%)
# microwave    / textured   : 10/10 (100.0%)
# trophy       / textured   : 7/10 (70.0%)
# fan          / textured   : 8/10 (80.0%)
# lei          / textured   : 10/10 (100.0%)
# stapler      / textured   : 9/10 (90.0%)
# stapler      / smooth     : 8/10 (80.0%)
# exercise_equipment / textured   : 10/10 (100.0%)
# exercise_equipment / smooth     : 9/10 (90.0%)
# handgun      / textured   : 10/10 (100.0%)
# seashell     / textured   : 10/10 (100.0%)
# powerstrip   / textured   : 10/10 (100.0%)
# lipstick     / smooth     : 10/10 (100.0%)
# lantern      / textured   : 10/10 (100.0%)
# doorknob     / smooth     : 8/10 (80.0%)
# doorknob     / textured   : 8/10 (80.0%)
# abacus       / textured   : 9/10 (90.0%)
# jack-o-lantern / textured   : 10/10 (100.0%)
# camcorder    / textured   : 8/10 (80.0%)
# bird         / textured   : 10/10 (100.0%)
# saddle       / textured   : 10/10 (100.0%)
# saddle       / smooth     : 8/10 (80.0%)
# handbag      / textured   : 7/10 (70.0%)
# stool        / textured   : 3/10 (30.0%)
# stool        / smooth     : 8/10 (80.0%)
# toyrabbit    / textured   : 10/10 (100.0%)
# candleholderwithcandle / textured   : 7/10 (70.0%)
# candleholderwithcandle / smooth     : 9/10 (90.0%)
# cushion      / smooth     : 10/10 (100.0%)
# cushion      / textured   : 8/10 (80.0%)
# lock         / textured   : 6/10 (60.0%)
# lock         / smooth     : 7/10 (70.0%)
# train        / smooth     : 8/10 (80.0%)
# train        / textured   : 9/10 (90.0%)
# bonzai       / textured   : 10/10 (100.0%)
# ring         / textured   : 5/10 (50.0%)
# goggle       / smooth     : 10/10 (100.0%)
# goggle       / textured   : 8/10 (80.0%)
# trumpet      / smooth     : 10/10 (100.0%)
# vase         / textured   : 7/10 (70.0%)
# vase         / smooth     : 5/10 (50.0%)
# axe          / textured   : 10/10 (100.0%)
# tricycle     / smooth     : 9/10 (90.0%)
# toothpaste   / smooth     : 9/10 (90.0%)
# nailpolish   / smooth     : 9/10 (90.0%)
# calculator   / textured   : 9/10 (90.0%)
# pen          / smooth     : 10/10 (100.0%)
# tree         / textured   : 10/10 (100.0%)
# earings      / textured   : 5/10 (50.0%)
# toyhorse     / textured   : 10/10 (100.0%)
# toyhorse     / smooth     : 10/10 (100.0%)
# gamehandheld / smooth     : 8/10 (80.0%)
# gamehandheld / textured   : 2/10 (20.0%)
# apple        / smooth     : 10/10 (100.0%)
# babushkadolls / smooth     : 10/10 (100.0%)
# saltpeppershake / textured   : 6/10 (60.0%)
# saltpeppershake / smooth     : 10/10 (100.0%)
# dresser      / textured   : 10/10 (100.0%)
# rug          / textured   : 10/10 (100.0%)
# wineglass    / smooth     : 10/10 (100.0%)
# wineglass    / textured   : 10/10 (100.0%)
# breadloaf    / textured   : 9/10 (90.0%)
# keyboard     / textured   : 10/10 (100.0%)
# meat         / textured   : 10/10 (100.0%)
# sippycup     / smooth     : 8/10 (80.0%)
# sippycup     / textured   : 9/10 (90.0%)
# cookie       / textured   : 10/10 (100.0%)
# helmet       / textured   : 9/10 (90.0%)
# helmet       / smooth     : 7/10 (70.0%)
# doll         / textured   : 10/10 (100.0%)
# pipe         / textured   : 7/10 (70.0%)
# pipe         / smooth     : 9/10 (90.0%)
# christmastreeornamantball / textured   : 10/10 (100.0%)
# christmastreeornamantball / smooth     : 10/10 (100.0%)
# telescope    / smooth     : 10/10 (100.0%)
# telescope    / textured   : 3/10 (30.0%)
# suitcase     / smooth     : 9/10 (90.0%)
# suitcase     / textured   : 7/10 (70.0%)
#
# [OK] Overall accuracy: 797/920 (86.6%)
#
# CVCL Results by Class-Texture:
# butterfly-textured       : 10/10 (100.0%)
# muffins-textured         : 10/10 (100.0%)
# pitcher-textured         : 9/10 (90.0%)
# pitcher-smooth           : 9/10 (90.0%)
# tennisracquet-textured   : 10/10 (100.0%)
# phone-textured           : 8/10 (80.0%)
# headband-textured        : 6/10 (60.0%)
# headband-smooth          : 8/10 (80.0%)
# bagel-textured           : 10/10 (100.0%)
# grill-smooth             : 9/10 (90.0%)
# grill-textured           : 7/10 (70.0%)
# basket-textured          : 10/10 (100.0%)
# bell-smooth              : 8/10 (80.0%)
# bell-textured            : 10/10 (100.0%)
# sodacan-smooth           : 10/10 (100.0%)
# microwave-textured       : 10/10 (100.0%)
# trophy-textured          : 7/10 (70.0%)
# fan-textured             : 8/10 (80.0%)
# lei-textured             : 10/10 (100.0%)
# stapler-textured         : 9/10 (90.0%)
# stapler-smooth           : 8/10 (80.0%)
# exercise_equipment-textured: 10/10 (100.0%)
# exercise_equipment-smooth: 9/10 (90.0%)
# handgun-textured         : 10/10 (100.0%)
# seashell-textured        : 10/10 (100.0%)
# powerstrip-textured      : 10/10 (100.0%)
# lipstick-smooth          : 10/10 (100.0%)
# lantern-textured         : 10/10 (100.0%)
# doorknob-smooth          : 8/10 (80.0%)
# doorknob-textured        : 8/10 (80.0%)
# abacus-textured          : 9/10 (90.0%)
# jack-o-lantern-textured  : 10/10 (100.0%)
# camcorder-textured       : 8/10 (80.0%)
# bird-textured            : 10/10 (100.0%)
# saddle-textured          : 10/10 (100.0%)
# saddle-smooth            : 8/10 (80.0%)
# handbag-textured         : 7/10 (70.0%)
# stool-textured           : 3/10 (30.0%)
# stool-smooth             : 8/10 (80.0%)
# toyrabbit-textured       : 10/10 (100.0%)
# candleholderwithcandle-textured: 7/10 (70.0%)
# candleholderwithcandle-smooth: 9/10 (90.0%)
# cushion-smooth           : 10/10 (100.0%)
# cushion-textured         : 8/10 (80.0%)
# lock-textured            : 6/10 (60.0%)
# lock-smooth              : 7/10 (70.0%)
# train-smooth             : 8/10 (80.0%)
# train-textured           : 9/10 (90.0%)
# bonzai-textured          : 10/10 (100.0%)
# ring-textured            : 5/10 (50.0%)
# goggle-smooth            : 10/10 (100.0%)
# goggle-textured          : 8/10 (80.0%)
# trumpet-smooth           : 10/10 (100.0%)
# vase-textured            : 7/10 (70.0%)
# vase-smooth              : 5/10 (50.0%)
# axe-textured             : 10/10 (100.0%)
# tricycle-smooth          : 9/10 (90.0%)
# toothpaste-smooth        : 9/10 (90.0%)
# nailpolish-smooth        : 9/10 (90.0%)
# calculator-textured      : 9/10 (90.0%)
# pen-smooth               : 10/10 (100.0%)
# tree-textured            : 10/10 (100.0%)
# earings-textured         : 5/10 (50.0%)
# toyhorse-textured        : 10/10 (100.0%)
# toyhorse-smooth          : 10/10 (100.0%)
# gamehandheld-smooth      : 8/10 (80.0%)
# gamehandheld-textured    : 2/10 (20.0%)
# apple-smooth             : 10/10 (100.0%)
# babushkadolls-smooth     : 10/10 (100.0%)
# saltpeppershake-textured : 6/10 (60.0%)
# saltpeppershake-smooth   : 10/10 (100.0%)
# dresser-textured         : 10/10 (100.0%)
# rug-textured             : 10/10 (100.0%)
# wineglass-smooth         : 10/10 (100.0%)
# wineglass-textured       : 10/10 (100.0%)
# breadloaf-textured       : 9/10 (90.0%)
# keyboard-textured        : 10/10 (100.0%)
# meat-textured            : 10/10 (100.0%)
# sippycup-smooth          : 8/10 (80.0%)
# sippycup-textured        : 9/10 (90.0%)
# cookie-textured          : 10/10 (100.0%)
# helmet-textured          : 9/10 (90.0%)
# helmet-smooth            : 7/10 (70.0%)
# doll-textured            : 10/10 (100.0%)
# pipe-textured            : 7/10 (70.0%)
# pipe-smooth              : 9/10 (90.0%)
# christmastreeornamantball-textured: 10/10 (100.0%)
# christmastreeornamantball-smooth: 10/10 (100.0%)
# telescope-smooth         : 10/10 (100.0%)
# telescope-textured       : 3/10 (30.0%)
# suitcase-smooth          : 9/10 (90.0%)
# suitcase-textured        : 7/10 (70.0%)
#
# CVCL Overall Accuracy: 86.6%

# %% [markdown]
# ## CLIP Test

# %%
# Run CLIP evaluation
clip_results, clip_overall = run_dcdt_test('clip-resnext')

print("\nCLIP Results by Class-Texture:")
for key, res in clip_results.items():
    print(f"{key:25s}: {res['correct']}/{res['trials']} ({res['accuracy']:.1%})")
print(f"\nCLIP Overall Accuracy: {clip_overall:.1%}")
# Out:
# [INFO] Loaded model 'clip-resnext'
# c:\Users\jbats\miniconda3\envs\ntu-synthetic\lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# [INFO] Extracted embeddings for 1005 images
# [INFO] Running 4-way trials: distractors with different class AND different texture
# butterfly    / textured   : 10/10 (100.0%)
# muffins      / textured   : 10/10 (100.0%)
# pitcher      / textured   : 10/10 (100.0%)
# pitcher      / smooth     : 10/10 (100.0%)
# tennisracquet / textured   : 10/10 (100.0%)
# phone        / textured   : 10/10 (100.0%)
# headband     / textured   : 10/10 (100.0%)
# headband     / smooth     : 10/10 (100.0%)
# bagel        / textured   : 10/10 (100.0%)
# grill        / smooth     : 10/10 (100.0%)
# grill        / textured   : 10/10 (100.0%)
# basket       / textured   : 10/10 (100.0%)
# bell         / smooth     : 9/10 (90.0%)
# bell         / textured   : 9/10 (90.0%)
# sodacan      / smooth     : 10/10 (100.0%)
# microwave    / textured   : 10/10 (100.0%)
# trophy       / textured   : 10/10 (100.0%)
# fan          / textured   : 10/10 (100.0%)
# lei          / textured   : 10/10 (100.0%)
# stapler      / textured   : 10/10 (100.0%)
# stapler      / smooth     : 10/10 (100.0%)
# exercise_equipment / textured   : 10/10 (100.0%)
# exercise_equipment / smooth     : 10/10 (100.0%)
# handgun      / textured   : 10/10 (100.0%)
# seashell     / textured   : 10/10 (100.0%)
# powerstrip   / textured   : 9/10 (90.0%)
# lipstick     / smooth     : 10/10 (100.0%)
# lantern      / textured   : 10/10 (100.0%)
# doorknob     / smooth     : 9/10 (90.0%)
# doorknob     / textured   : 10/10 (100.0%)
# abacus       / textured   : 10/10 (100.0%)
# jack-o-lantern / textured   : 10/10 (100.0%)
# camcorder    / textured   : 10/10 (100.0%)
# bird         / textured   : 10/10 (100.0%)
# saddle       / textured   : 10/10 (100.0%)
# saddle       / smooth     : 10/10 (100.0%)
# handbag      / textured   : 10/10 (100.0%)
# stool        / textured   : 10/10 (100.0%)
# stool        / smooth     : 10/10 (100.0%)
# toyrabbit    / textured   : 10/10 (100.0%)
# candleholderwithcandle / textured   : 10/10 (100.0%)
# candleholderwithcandle / smooth     : 10/10 (100.0%)
# cushion      / smooth     : 10/10 (100.0%)
# cushion      / textured   : 10/10 (100.0%)
# lock         / textured   : 10/10 (100.0%)
# lock         / smooth     : 10/10 (100.0%)
# train        / smooth     : 10/10 (100.0%)
# train        / textured   : 10/10 (100.0%)
# bonzai       / textured   : 10/10 (100.0%)
# ring         / textured   : 10/10 (100.0%)
# goggle       / smooth     : 10/10 (100.0%)
# goggle       / textured   : 10/10 (100.0%)
# trumpet      / smooth     : 10/10 (100.0%)
# vase         / textured   : 9/10 (90.0%)
# vase         / smooth     : 10/10 (100.0%)
# axe          / textured   : 10/10 (100.0%)
# tricycle     / smooth     : 10/10 (100.0%)
# toothpaste   / smooth     : 10/10 (100.0%)
# nailpolish   / smooth     : 10/10 (100.0%)
# calculator   / textured   : 10/10 (100.0%)
# pen          / smooth     : 10/10 (100.0%)
# tree         / textured   : 10/10 (100.0%)
# earings      / textured   : 10/10 (100.0%)
# toyhorse     / textured   : 10/10 (100.0%)
# toyhorse     / smooth     : 10/10 (100.0%)
# gamehandheld / smooth     : 10/10 (100.0%)
# gamehandheld / textured   : 10/10 (100.0%)
# apple        / smooth     : 10/10 (100.0%)
# babushkadolls / smooth     : 10/10 (100.0%)
# saltpeppershake / textured   : 9/10 (90.0%)
# saltpeppershake / smooth     : 10/10 (100.0%)
# dresser      / textured   : 10/10 (100.0%)
# rug          / textured   : 10/10 (100.0%)
# wineglass    / smooth     : 10/10 (100.0%)
# wineglass    / textured   : 10/10 (100.0%)
# breadloaf    / textured   : 10/10 (100.0%)
# keyboard     / textured   : 10/10 (100.0%)
# meat         / textured   : 10/10 (100.0%)
# sippycup     / smooth     : 10/10 (100.0%)
# sippycup     / textured   : 10/10 (100.0%)
# cookie       / textured   : 10/10 (100.0%)
# helmet       / textured   : 10/10 (100.0%)
# helmet       / smooth     : 10/10 (100.0%)
# doll         / textured   : 10/10 (100.0%)
# pipe         / textured   : 9/10 (90.0%)
# pipe         / smooth     : 9/10 (90.0%)
# christmastreeornamantball / textured   : 10/10 (100.0%)
# christmastreeornamantball / smooth     : 10/10 (100.0%)
# telescope    / smooth     : 10/10 (100.0%)
# telescope    / textured   : 5/10 (50.0%)
# suitcase     / smooth     : 10/10 (100.0%)
# suitcase     / textured   : 10/10 (100.0%)
#
# [OK] Overall accuracy: 907/920 (98.6%)
#
# CLIP Results by Class-Texture:
# butterfly-textured       : 10/10 (100.0%)
# muffins-textured         : 10/10 (100.0%)
# pitcher-textured         : 10/10 (100.0%)
# pitcher-smooth           : 10/10 (100.0%)
# tennisracquet-textured   : 10/10 (100.0%)
# phone-textured           : 10/10 (100.0%)
# headband-textured        : 10/10 (100.0%)
# headband-smooth          : 10/10 (100.0%)
# bagel-textured           : 10/10 (100.0%)
# grill-smooth             : 10/10 (100.0%)
# grill-textured           : 10/10 (100.0%)
# basket-textured          : 10/10 (100.0%)
# bell-smooth              : 9/10 (90.0%)
# bell-textured            : 9/10 (90.0%)
# sodacan-smooth           : 10/10 (100.0%)
# microwave-textured       : 10/10 (100.0%)
# trophy-textured          : 10/10 (100.0%)
# fan-textured             : 10/10 (100.0%)
# lei-textured             : 10/10 (100.0%)
# stapler-textured         : 10/10 (100.0%)
# stapler-smooth           : 10/10 (100.0%)
# exercise_equipment-textured: 10/10 (100.0%)
# exercise_equipment-smooth: 10/10 (100.0%)
# handgun-textured         : 10/10 (100.0%)
# seashell-textured        : 10/10 (100.0%)
# powerstrip-textured      : 9/10 (90.0%)
# lipstick-smooth          : 10/10 (100.0%)
# lantern-textured         : 10/10 (100.0%)
# doorknob-smooth          : 9/10 (90.0%)
# doorknob-textured        : 10/10 (100.0%)
# abacus-textured          : 10/10 (100.0%)
# jack-o-lantern-textured  : 10/10 (100.0%)
# camcorder-textured       : 10/10 (100.0%)
# bird-textured            : 10/10 (100.0%)
# saddle-textured          : 10/10 (100.0%)
# saddle-smooth            : 10/10 (100.0%)
# handbag-textured         : 10/10 (100.0%)
# stool-textured           : 10/10 (100.0%)
# stool-smooth             : 10/10 (100.0%)
# toyrabbit-textured       : 10/10 (100.0%)
# candleholderwithcandle-textured: 10/10 (100.0%)
# candleholderwithcandle-smooth: 10/10 (100.0%)
# cushion-smooth           : 10/10 (100.0%)
# cushion-textured         : 10/10 (100.0%)
# lock-textured            : 10/10 (100.0%)
# lock-smooth              : 10/10 (100.0%)
# train-smooth             : 10/10 (100.0%)
# train-textured           : 10/10 (100.0%)
# bonzai-textured          : 10/10 (100.0%)
# ring-textured            : 10/10 (100.0%)
# goggle-smooth            : 10/10 (100.0%)
# goggle-textured          : 10/10 (100.0%)
# trumpet-smooth           : 10/10 (100.0%)
# vase-textured            : 9/10 (90.0%)
# vase-smooth              : 10/10 (100.0%)
# axe-textured             : 10/10 (100.0%)
# tricycle-smooth          : 10/10 (100.0%)
# toothpaste-smooth        : 10/10 (100.0%)
# nailpolish-smooth        : 10/10 (100.0%)
# calculator-textured      : 10/10 (100.0%)
# pen-smooth               : 10/10 (100.0%)
# tree-textured            : 10/10 (100.0%)
# earings-textured         : 10/10 (100.0%)
# toyhorse-textured        : 10/10 (100.0%)
# toyhorse-smooth          : 10/10 (100.0%)
# gamehandheld-smooth      : 10/10 (100.0%)
# gamehandheld-textured    : 10/10 (100.0%)
# apple-smooth             : 10/10 (100.0%)
# babushkadolls-smooth     : 10/10 (100.0%)
# saltpeppershake-textured : 9/10 (90.0%)
# saltpeppershake-smooth   : 10/10 (100.0%)
# dresser-textured         : 10/10 (100.0%)
# rug-textured             : 10/10 (100.0%)
# wineglass-smooth         : 10/10 (100.0%)
# wineglass-textured       : 10/10 (100.0%)
# breadloaf-textured       : 10/10 (100.0%)
# keyboard-textured        : 10/10 (100.0%)
# meat-textured            : 10/10 (100.0%)
# sippycup-smooth          : 10/10 (100.0%)
# sippycup-textured        : 10/10 (100.0%)
# cookie-textured          : 10/10 (100.0%)
# helmet-textured          : 10/10 (100.0%)
# helmet-smooth            : 10/10 (100.0%)
# doll-textured            : 10/10 (100.0%)
# pipe-textured            : 9/10 (90.0%)
# pipe-smooth              : 9/10 (90.0%)
# christmastreeornamantball-textured: 10/10 (100.0%)
# christmastreeornamantball-smooth: 10/10 (100.0%)
# telescope-smooth         : 10/10 (100.0%)
# telescope-textured       : 5/10 (50.0%)
# suitcase-smooth          : 10/10 (100.0%)
# suitcase-textured        : 10/10 (100.0%)
#
# CLIP Overall Accuracy: 98.6%
