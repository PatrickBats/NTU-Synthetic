# %% [markdown]
# # Same Class Different Colors (SCDC) Comparison
#
# This notebook compares CVCL and CLIP models on color prototype evaluation within the same class.
# For example, testing if a model can distinguish between red and green apples using color prototypes.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------------------------- ------- 10.5/12.8 MB 72.5 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 61.8 MB/s  0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os
import sys
import random
import torch
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from collections import defaultdict

# ─── Path setup ───
REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir, os.pardir, os.pardir))

# Add discover-hidden-visual-concepts to path
DISCOVER_ROOT = os.path.join(REPO_ROOT, 'discover-hidden-visual-concepts')
sys.path.insert(0, DISCOVER_ROOT)
sys.path.insert(0, REPO_ROOT)

# Import from discover-hidden-visual-concepts repo
sys.path.append(os.path.join(DISCOVER_ROOT, 'src'))
from utils.model_loader import load_model
from models.feature_extractor import FeatureExtractor
from models.multimodal.multimodal_lit import MultiModalLitModel

# ─── hard-coded paths ───
CSV_PATH = os.path.join(REPO_ROOT, 'data', 'KonkLab', 'testdata.csv')
IMG_DIR = os.path.join(REPO_ROOT, 'data', 'KonkLab', '17-objects')
MASTER_CSV = os.path.join(REPO_ROOT, 'PatrickProject', 'Chart_Generation', 'all_prototype_results.csv')

# %%
# Shared Dataset and Helper Functions
class ColorImageDataset(Dataset):
    def __init__(self, csv_path, img_dir, transform):
        self.df = pd.read_csv(csv_path)
        assert all(col in self.df for col in ['Filename','Class','Color']), \
            "CSV must have Filename, Class, and Color columns"
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        cls, fn = row['Class'], row['Filename']
        path = os.path.join(self.img_dir, cls, fn)
        img = Image.open(path).convert('RGB')
        return self.transform(img), row['Class'], row['Color'], idx

def collate_fn(batch):
    imgs = torch.stack([b[0] for b in batch])
    classes = [b[1] for b in batch]
    colors = [b[2] for b in batch]
    idxs = [b[3] for b in batch]
    return imgs, classes, colors, idxs

def run_scdc_test(model_name, seed=0, device='cuda' if torch.cuda.is_available() else 'cpu',
                  batch_size=64, trials_per_class=10, max_images=None, max_trials=4000):
    """
    Run Same Class Different Colors (SCDC) test.
    
    This test evaluates whether models can distinguish between different colors 
    of the SAME class. For example: red apple vs green apple vs yellow apple.
    
    Distractors are only from the same class but different colors, making this
    a harder test focused purely on color discrimination within object categories.
    """
    random.seed(seed)
    torch.manual_seed(seed)

    # 1) load model & transform
    model, transform = load_model(model_name, seed=seed, device=device)
    extractor = FeatureExtractor(model_name, model, device)

    # 2) load data + extract embeddings
    full_ds = ColorImageDataset(CSV_PATH, IMG_DIR, transform)
    full_loader = DataLoader(
        full_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,  # Avoid worker issues on Windows
        collate_fn=collate_fn
    )
    print(f"[ℹ️] Full dataset size: {len(full_ds)} samples")

    # 3) extract embeddings for all images
    all_embs, all_classes, all_colors, all_idxs = [], [], [], []
    with torch.no_grad():
        for imgs, classes, colors, idxs in full_loader:
            feats = extractor.get_img_feature(imgs.to(device))
            feats = extractor.norm_features(feats)
            feats = feats.float()  # ensure float dtype
            all_embs.append(feats.cpu())
            all_classes.extend(classes)
            all_colors.extend(colors)
            all_idxs.extend(idxs)
    all_embs = torch.cat(all_embs, dim=0)  # [N, D]

    # 4) organize by class -> color
    class_color_idxs = defaultdict(lambda: defaultdict(list))
    for idx, cls, col in zip(all_idxs, all_classes, all_colors):
        class_color_idxs[cls][col].append(idx)

    # 5) Calculate all valid combinations
    all_combinations = []
    for cls, color_groups in class_color_idxs.items():
        for color, idx_list in color_groups.items():
            # Pick distractors only from *other colors* of *the same class*
            other_idxs = [
                i for col2, lst2 in color_groups.items() if col2 != color
                for i in lst2
            ]
            if len(idx_list) >= 1 and len(other_idxs) >= 3:
                all_combinations.append((cls, color, idx_list, other_idxs))
    
    # Adjust trials per combination to stay under max_trials
    total_combinations = len(all_combinations)
    if total_combinations * trials_per_class > max_trials:
        trials_per_combo = max(1, max_trials // total_combinations)
        print(f"[INFO] Limiting to {trials_per_combo} trials per combination to stay under {max_trials} total trials")
    else:
        trials_per_combo = trials_per_class

    # 6) run within-class 4-way trials
    total_correct = 0
    total_trials = 0
    class_color_results = {}

    print("[ℹ️] Running 4-way color-vs-other-color trials *within each class* ...")
    for cls, color, idx_list, other_idxs in all_combinations:
        if total_trials >= max_trials:
            print(f"[INFO] Reached maximum trials limit ({max_trials})")
            break

        correct = 0
        actual_trials = min(trials_per_combo, max_trials - total_trials)
        
        for _ in range(actual_trials):
            q = random.choice(idx_list)
            same_color = [i for i in idx_list if i != q]
            proto = all_embs[[all_idxs.index(i) for i in same_color]].mean(0)
            proto = proto / proto.norm()

            distractors = random.sample(other_idxs, 3)
            candidates = [q] + distractors
            feats_cand = all_embs[[all_idxs.index(i) for i in candidates]]
            sims = feats_cand @ proto
            guess = candidates[sims.argmax().item()]

            total_correct += int(guess == q)
            total_trials += 1
            correct += int(guess == q)

        acc = correct / actual_trials if actual_trials > 0 else 0
        key = f"{cls}-{color}"
        class_color_results[key] = {
            'correct': correct,
            'trials': actual_trials,
            'accuracy': acc
        }
        print(f"{cls:20s} / {color:12s}: {correct}/{actual_trials} ({acc:.1%})")

    overall_acc = total_correct / total_trials if total_trials else 0.0
    print(f"\nOverall accuracy: {total_correct}/{total_trials} ({overall_acc:.1%})")

    # 7) save results
    summary_df = pd.DataFrame([{
        'Model': model_name,
        'Test': 'Same-Class-Different-Colors',
        'Correct': total_correct,
        'Trials': total_trials,
        'Accuracy': overall_acc
    }])
    
    os.makedirs(os.path.dirname(MASTER_CSV), exist_ok=True)
    if os.path.exists(MASTER_CSV):
        summary_df.to_csv(MASTER_CSV, mode='a', header=False, index=False, float_format='%.4f')
    else:
        summary_df.to_csv(MASTER_CSV, index=False, float_format='%.4f')

    return class_color_results, overall_acc

# %% [markdown]
# ## CVCL Color Test

# %%
# Run CVCL color evaluation
cvcl_results, cvcl_overall = run_scdc_test('cvcl-resnext')

print("\nCVCL Results by Class-Color:")
for key, res in cvcl_results.items():
    print(f"{key:24s}: {res['correct']}/{res['trials']} ({res['accuracy']:.1%})")
print(f"\nCVCL Overall Accuracy: {cvcl_overall:.1%}")
# Out:
# Loading checkpoint from C:\Users\jbats\.cache\huggingface\hub\models--wkvong--cvcl_s_dino_resnext50_embedding\snapshots\f50eaa0c50a6076a5190b1dd52aeeb6c3e747045\cvcl_s_dino_resnext50_embedding.ckpt
# Lightning automatically upgraded your loaded checkpoint from v1.5.8 to v2.5.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\jbats\.cache\huggingface\hub\models--wkvong--cvcl_s_dino_resnext50_embedding\snapshots\f50eaa0c50a6076a5190b1dd52aeeb6c3e747045\cvcl_s_dino_resnext50_embedding.ckpt`
# CVCL Results by Class-Color:
# butterfly-Multicolored  : 7/10 (70.0%)
# butterfly-Yellow        : 0/10 (0.0%)
# butterfly-Red           : 10/10 (100.0%)
# muffins-Multicolored    : 0/10 (0.0%)
# muffins-Orange          : 1/10 (10.0%)
# muffins-Yellow          : 5/10 (50.0%)
# pitcher-Yellow          : 0/10 (0.0%)
# pitcher-Multicolored    : 0/10 (0.0%)
# pitcher-Green           : 2/10 (20.0%)
# pitcher-Grey            : 3/10 (30.0%)
# pitcher-Orange          : 8/10 (80.0%)
# pitcher-Blue            : 0/10 (0.0%)
# tennisracquet-Multicolored: 0/10 (0.0%)
# tennisracquet-Grey      : 6/10 (60.0%)
# tennisracquet-Pink      : 10/10 (100.0%)
# tennisracquet-Green     : 10/10 (100.0%)
# phone-Grey              : 0/10 (0.0%)
# phone-Blue              : 0/10 (0.0%)
# phone-Yellow            : 2/10 (20.0%)
# phone-Green             : 10/10 (100.0%)
# phone-Red               : 10/10 (100.0%)
# phone-Multicolored      : 0/10 (0.0%)
# headband-Multicolored   : 6/10 (60.0%)
# headband-Purple         : 10/10 (100.0%)
# headband-Grey           : 10/10 (100.0%)
# headband-Orange         : 10/10 (100.0%)
# headband-Red            : 10/10 (100.0%)
# headband-Pink           : 10/10 (100.0%)
# bagel-Multicolored      : 4/10 (40.0%)
# bagel-Orange            : 1/10 (10.0%)
# bagel-Yellow            : 1/10 (10.0%)
# grill-Multicolored      : 4/10 (40.0%)
# grill-Grey              : 5/10 (50.0%)
# grill-Black             : 10/10 (100.0%)
# grill-Blue              : 10/10 (100.0%)
# basket-Yellow           : 0/10 (0.0%)
# basket-Multicolored     : 0/10 (0.0%)
# basket-Orange           : 7/10 (70.0%)
# basket-Grey             : 10/10 (100.0%)
# bell-Yellow             : 4/10 (40.0%)
# bell-Grey               : 2/10 (20.0%)
# bell-Multicolored       : 2/10 (20.0%)
# microwave-Grey          : 5/10 (50.0%)
# microwave-Multicolored  : 0/10 (0.0%)
# microwave-White         : 10/10 (100.0%)
# microwave-Blue          : 10/10 (100.0%)
# trophy-Orange           : 2/10 (20.0%)
# trophy-Multicolored     : 6/10 (60.0%)
# trophy-Yellow           : 0/10 (0.0%)
# trophy-Red              : 10/10 (100.0%)
# fan-Multicolored        : 1/10 (10.0%)
# fan-Grey                : 4/10 (40.0%)
# fan-Orange              : 10/10 (100.0%)
# fan-Blue                : 10/10 (100.0%)
# lei-Green               : 10/10 (100.0%)
# lei-Multicolored        : 5/10 (50.0%)
# lei-Yellow              : 10/10 (100.0%)
# lei-Red                 : 2/10 (20.0%)
# stapler-Red             : 2/10 (20.0%)
# stapler-Multicolored    : 2/10 (20.0%)
# stapler-Blue            : 1/10 (10.0%)
# stapler-Grey            : 5/10 (50.0%)
# stapler-Pink            : 10/10 (100.0%)
# stapler-Purple          : 10/10 (100.0%)
# exercise_equipment-Grey : 2/10 (20.0%)
# exercise_equipment-Blue : 10/10 (100.0%)
# exercise_equipment-Multicolored: 3/10 (30.0%)
# exercise_equipment-Black: 10/10 (100.0%)
# handgun-Orange          : 10/10 (100.0%)
# handgun-Blue            : 10/10 (100.0%)
# seashell-Orange         : 8/10 (80.0%)
# seashell-Multicolored   : 0/10 (0.0%)
# seashell-Yellow         : 2/10 (20.0%)
# powerstrip-White        : 10/10 (100.0%)
# powerstrip-Grey         : 8/10 (80.0%)
# powerstrip-Black        : 0/10 (0.0%)
# powerstrip-Multicolored : 6/10 (60.0%)
# lipstick-Grey           : 8/10 (80.0%)
# lipstick-Multicolored   : 3/10 (30.0%)
# lipstick-Black          : 10/10 (100.0%)
# lipstick-Yellow         : 10/10 (100.0%)
# lantern-Multicolored    : 4/10 (40.0%)
# lantern-Red             : 0/10 (0.0%)
# lantern-Blue            : 10/10 (100.0%)
# lantern-Orange          : 10/10 (100.0%)
# lantern-Yellow          : 10/10 (100.0%)
# doorknob-Yellow         : 0/10 (0.0%)
# doorknob-Grey           : 2/10 (20.0%)
# doorknob-Red            : 10/10 (100.0%)
# doorknob-Multicolored   : 4/10 (40.0%)
# doorknob-Orange         : 10/10 (100.0%)
# abacus-Multicolored     : 0/10 (0.0%)
# abacus-Orange           : 2/10 (20.0%)
# jack-o-lantern-Orange   : 2/10 (20.0%)
# jack-o-lantern-Multicolored: 1/10 (10.0%)
# jack-o-lantern-Yellow   : 10/10 (100.0%)
# camcorder-Grey          : 7/10 (70.0%)
# camcorder-Multicolored  : 5/10 (50.0%)
# camcorder-Blue          : 10/10 (100.0%)
# bird-White              : 10/10 (100.0%)
# bird-Multicolored       : 2/10 (20.0%)
# bird-Grey               : 6/10 (60.0%)
# bird-Orange             : 10/10 (100.0%)
# saddle-Multicolored     : 2/10 (20.0%)
# saddle-Yellow           : 10/10 (100.0%)
# saddle-Brown            : 0/10 (0.0%)
# saddle-Orange           : 5/10 (50.0%)
# saddle-Grey             : 0/10 (0.0%)
# saddle-Red              : 10/10 (100.0%)
# handbag-Multicolored    : 1/10 (10.0%)
# handbag-Blue            : 0/10 (0.0%)
# handbag-Yellow          : 3/10 (30.0%)
# handbag-Orange          : 10/10 (100.0%)
# handbag-Red             : 10/10 (100.0%)
# handbag-Grey            : 10/10 (100.0%)
# stool-Yellow            : 10/10 (100.0%)
# stool-Grey              : 2/10 (20.0%)
# stool-Multicolored      : 1/10 (10.0%)
# stool-Orange            : 10/10 (100.0%)
# toyrabbit-Multicolored  : 3/10 (30.0%)
# toyrabbit-White         : 10/10 (100.0%)
# toyrabbit-Grey          : 3/10 (30.0%)
# candleholderwithcandle-Multicolored: 2/10 (20.0%)
# candleholderwithcandle-Yellow: 8/10 (80.0%)
# candleholderwithcandle-Orange: 10/10 (100.0%)
# cushion-Multicolored    : 5/10 (50.0%)
# cushion-Orange          : 10/10 (100.0%)
# cushion-Red             : 0/10 (0.0%)
# cushion-Grey            : 10/10 (100.0%)
# cushion-Blue            : 10/10 (100.0%)
# lock-Orange             : 10/10 (100.0%)
# lock-Multicolored       : 3/10 (30.0%)
# lock-Yellow             : 10/10 (100.0%)
# lock-Grey               : 0/10 (0.0%)
# train-Blue              : 10/10 (100.0%)
# train-Orange            : 10/10 (100.0%)
# ring-Grey               : 7/10 (70.0%)
# ring-Multicolored       : 0/10 (0.0%)
# ring-Yellow             : 6/10 (60.0%)
# goggle-Multicolored     : 3/10 (30.0%)
# goggle-Grey             : 2/10 (20.0%)
# goggle-Yellow           : 10/10 (100.0%)
# goggle-Blue             : 10/10 (100.0%)
# trumpet-Grey            : 5/10 (50.0%)
# trumpet-Green           : 10/10 (100.0%)
# trumpet-Yellow          : 3/10 (30.0%)
# trumpet-Orange          : 10/10 (100.0%)
# trumpet-Red             : 10/10 (100.0%)
# vase-Multicolored       : 6/10 (60.0%)
# vase-Green              : 10/10 (100.0%)
# vase-Grey               : 10/10 (100.0%)
# vase-Yellow             : 7/10 (70.0%)
# vase-Orange             : 7/10 (70.0%)
# axe-Multicolored        : 3/10 (30.0%)
# axe-Orange              : 5/10 (50.0%)
# axe-Grey                : 7/10 (70.0%)
# axe-Red                 : 10/10 (100.0%)
# tricycle-Multicolored   : 5/10 (50.0%)
# tricycle-Red            : 0/10 (0.0%)
# tricycle-Blue           : 0/10 (0.0%)
# tricycle-Grey           : 10/10 (100.0%)
# toothpaste-Multicolored : 5/10 (50.0%)
# toothpaste-Green        : 0/10 (0.0%)
# toothpaste-Red          : 4/10 (40.0%)
# toothpaste-Grey         : 10/10 (100.0%)
# nailpolish-Purple       : 0/10 (0.0%)
# nailpolish-Brown        : 10/10 (100.0%)
# nailpolish-Blue         : 10/10 (100.0%)
# nailpolish-Grey         : 10/10 (100.0%)
# nailpolish-Pink         : 2/10 (20.0%)
# nailpolish-Multicolored : 10/10 (100.0%)
# nailpolish-Red          : 0/10 (0.0%)
# nailpolish-Yellow       : 10/10 (100.0%)
# nailpolish-Green        : 10/10 (100.0%)
# calculator-Multicolored : 2/10 (20.0%)
# calculator-Grey         : 0/10 (0.0%)
# calculator-Purple       : 10/10 (100.0%)
# pen-Blue                : 9/10 (90.0%)
# pen-Grey                : 9/10 (90.0%)
# pen-Multicolored        : 1/10 (10.0%)
# pen-Pink                : 10/10 (100.0%)
# tree-Yellow             : 10/10 (100.0%)
# tree-Green              : 10/10 (100.0%)
# earings-Multicolored    : 3/10 (30.0%)
# earings-Yellow          : 1/10 (10.0%)
# earings-Grey            : 0/10 (0.0%)
# earings-Green           : 10/10 (100.0%)
# toyhorse-Brown          : 0/10 (0.0%)
# toyhorse-Orange         : 3/10 (30.0%)
# toyhorse-Yellow         : 10/10 (100.0%)
# toyhorse-Multicolored   : 4/10 (40.0%)
# toyhorse-Grey           : 1/10 (10.0%)
# gamehandheld-Multicolored: 5/10 (50.0%)
# gamehandheld-Grey       : 0/10 (0.0%)
# gamehandheld-Pink       : 10/10 (100.0%)
# gamehandheld-Black      : 10/10 (100.0%)
# apple-Multicolored      : 2/10 (20.0%)
# apple-Red               : 1/10 (10.0%)
# apple-Green             : 10/10 (100.0%)
# apple-Yellow            : 8/10 (80.0%)
# apple-Orange            : 1/10 (10.0%)
# saltpeppershake-Multicolored: 2/10 (20.0%)
# saltpeppershake-Yellow  : 0/10 (0.0%)
# saltpeppershake-Grey    : 3/10 (30.0%)
# saltpeppershake-Brown   : 10/10 (100.0%)
# dresser-Brown           : 3/10 (30.0%)
# dresser-Orange          : 0/10 (0.0%)
# dresser-Red             : 10/10 (100.0%)
# rug-Yellow              : 10/10 (100.0%)
# rug-Multicolored        : 2/10 (20.0%)
# rug-Orange              : 0/10 (0.0%)
# wineglass-Grey          : 3/10 (30.0%)
# wineglass-Blue          : 8/10 (80.0%)
# wineglass-Green         : 10/10 (100.0%)
# wineglass-Multicolored  : 2/10 (20.0%)
# breadloaf-Brown         : 10/10 (100.0%)
# breadloaf-Multicolored  : 0/10 (0.0%)
# breadloaf-Orange        : 4/10 (40.0%)
# breadloaf-Yellow        : 5/10 (50.0%)
# keyboard-Multicolored   : 1/10 (10.0%)
# keyboard-Grey           : 3/10 (30.0%)
# keyboard-Black          : 3/10 (30.0%)
# keyboard-Blue           : 10/10 (100.0%)
# meat-Red                : 4/10 (40.0%)
# meat-Multicolored       : 1/10 (10.0%)
# meat-Orange             : 5/10 (50.0%)
# meat-Pink               : 10/10 (100.0%)
# sippycup-Multicolored   : 0/10 (0.0%)
# sippycup-Blue           : 5/10 (50.0%)
# sippycup-Green          : 10/10 (100.0%)
# cookie-Yellow           : 7/10 (70.0%)
# cookie-Multicolored     : 1/10 (10.0%)
# cookie-Brown            : 10/10 (100.0%)
# cookie-Orange           : 10/10 (100.0%)
# helmet-Red              : 10/10 (100.0%)
# helmet-Blue             : 0/10 (0.0%)
# helmet-Grey             : 10/10 (100.0%)
# helmet-Purple           : 10/10 (100.0%)
# helmet-Multicolored     : 6/10 (60.0%)
# helmet-White            : 10/10 (100.0%)
# helmet-Black            : 7/10 (70.0%)
# doll-Multicolored       : 1/10 (10.0%)
# doll-Pink               : 10/10 (100.0%)
# doll-Red                : 0/10 (0.0%)
# doll-Black              : 10/10 (100.0%)
# doll-White              : 10/10 (100.0%)
# doll-Blue               : 10/10 (100.0%)
# pipe-Black              : 4/10 (40.0%)
# pipe-Brown              : 3/10 (30.0%)
# pipe-Multicolored       : 3/10 (30.0%)
# pipe-Yellow             : 10/10 (100.0%)
# christmastreeornamantball-Multicolored: 0/10 (0.0%)
# christmastreeornamantball-Pink: 10/10 (100.0%)
# christmastreeornamantball-Brown: 10/10 (100.0%)
# christmastreeornamantball-Orange: 10/10 (100.0%)
# christmastreeornamantball-Green: 10/10 (100.0%)
# christmastreeornamantball-Red: 10/10 (100.0%)
# telescope-Multicolored  : 3/10 (30.0%)
# telescope-Grey          : 0/10 (0.0%)
# telescope-Black         : 2/10 (20.0%)
# suitcase-Multicolored   : 0/10 (0.0%)
# suitcase-Blue           : 8/10 (80.0%)
# suitcase-Brown          : 6/10 (60.0%)
# suitcase-Black          : 10/10 (100.0%)
# suitcase-Orange         : 10/10 (100.0%)
# suitcase-Pink           : 10/10 (100.0%)
# suitcase-Red            : 10/10 (100.0%)
#
# CVCL Overall Accuracy: 56.9%

# %% [markdown]
# ## CLIP Color Test

# %%
# Run CLIP color evaluation
clip_results, clip_overall = run_scdc_test('clip-resnext')

print("\nCLIP Results by Class-Color:")
for key, res in clip_results.items():
    print(f"{key:24s}: {res['correct']}/{res['trials']} ({res['accuracy']:.1%})")
print(f"\nCLIP Overall Accuracy: {clip_overall:.1%}")
# Out:
# c:\Users\jbats\miniconda3\envs\ntu-synthetic\lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# CLIP Results by Class-Color:
# butterfly-Multicolored  : 10/10 (100.0%)
# butterfly-Yellow        : 5/10 (50.0%)
# butterfly-Red           : 10/10 (100.0%)
# muffins-Multicolored    : 1/10 (10.0%)
# muffins-Orange          : 7/10 (70.0%)
# muffins-Yellow          : 0/10 (0.0%)
# pitcher-Yellow          : 0/10 (0.0%)
# pitcher-Multicolored    : 0/10 (0.0%)
# pitcher-Green           : 4/10 (40.0%)
# pitcher-Grey            : 2/10 (20.0%)
# pitcher-Orange          : 5/10 (50.0%)
# pitcher-Blue            : 0/10 (0.0%)
# tennisracquet-Multicolored: 2/10 (20.0%)
# tennisracquet-Grey      : 10/10 (100.0%)
# tennisracquet-Pink      : 10/10 (100.0%)
# tennisracquet-Green     : 10/10 (100.0%)
# phone-Grey              : 1/10 (10.0%)
# phone-Blue              : 4/10 (40.0%)
# phone-Yellow            : 2/10 (20.0%)
# phone-Green             : 10/10 (100.0%)
# phone-Red               : 10/10 (100.0%)
# phone-Multicolored      : 1/10 (10.0%)
# headband-Multicolored   : 1/10 (10.0%)
# headband-Purple         : 10/10 (100.0%)
# headband-Grey           : 10/10 (100.0%)
# headband-Orange         : 10/10 (100.0%)
# headband-Red            : 10/10 (100.0%)
# headband-Pink           : 10/10 (100.0%)
# bagel-Multicolored      : 5/10 (50.0%)
# bagel-Orange            : 6/10 (60.0%)
# bagel-Yellow            : 0/10 (0.0%)
# grill-Multicolored      : 2/10 (20.0%)
# grill-Grey              : 6/10 (60.0%)
# grill-Black             : 10/10 (100.0%)
# grill-Blue              : 10/10 (100.0%)
# basket-Yellow           : 0/10 (0.0%)
# basket-Multicolored     : 0/10 (0.0%)
# basket-Orange           : 6/10 (60.0%)
# basket-Grey             : 10/10 (100.0%)
# bell-Yellow             : 10/10 (100.0%)
# bell-Grey               : 3/10 (30.0%)
# bell-Multicolored       : 3/10 (30.0%)
# microwave-Grey          : 4/10 (40.0%)
# microwave-Multicolored  : 0/10 (0.0%)
# microwave-White         : 10/10 (100.0%)
# microwave-Blue          : 10/10 (100.0%)
# trophy-Orange           : 3/10 (30.0%)
# trophy-Multicolored     : 3/10 (30.0%)
# trophy-Yellow           : 3/10 (30.0%)
# trophy-Red              : 10/10 (100.0%)
# fan-Multicolored        : 0/10 (0.0%)
# fan-Grey                : 2/10 (20.0%)
# fan-Orange              : 10/10 (100.0%)
# fan-Blue                : 10/10 (100.0%)
# lei-Green               : 10/10 (100.0%)
# lei-Multicolored        : 1/10 (10.0%)
# lei-Yellow              : 10/10 (100.0%)
# lei-Red                 : 0/10 (0.0%)
# stapler-Red             : 9/10 (90.0%)
# stapler-Multicolored    : 5/10 (50.0%)
# stapler-Blue            : 8/10 (80.0%)
# stapler-Grey            : 10/10 (100.0%)
# stapler-Pink            : 10/10 (100.0%)
# stapler-Purple          : 10/10 (100.0%)
# exercise_equipment-Grey : 2/10 (20.0%)
# exercise_equipment-Blue : 10/10 (100.0%)
# exercise_equipment-Multicolored: 2/10 (20.0%)
# exercise_equipment-Black: 10/10 (100.0%)
# handgun-Orange          : 10/10 (100.0%)
# handgun-Blue            : 10/10 (100.0%)
# seashell-Orange         : 7/10 (70.0%)
# seashell-Multicolored   : 5/10 (50.0%)
# seashell-Yellow         : 0/10 (0.0%)
# powerstrip-White        : 10/10 (100.0%)
# powerstrip-Grey         : 3/10 (30.0%)
# powerstrip-Black        : 6/10 (60.0%)
# powerstrip-Multicolored : 5/10 (50.0%)
# lipstick-Grey           : 8/10 (80.0%)
# lipstick-Multicolored   : 4/10 (40.0%)
# lipstick-Black          : 10/10 (100.0%)
# lipstick-Yellow         : 10/10 (100.0%)
# lantern-Multicolored    : 4/10 (40.0%)
# lantern-Red             : 0/10 (0.0%)
# lantern-Blue            : 10/10 (100.0%)
# lantern-Orange          : 10/10 (100.0%)
# lantern-Yellow          : 10/10 (100.0%)
# doorknob-Yellow         : 4/10 (40.0%)
# doorknob-Grey           : 6/10 (60.0%)
# doorknob-Red            : 10/10 (100.0%)
# doorknob-Multicolored   : 2/10 (20.0%)
# doorknob-Orange         : 10/10 (100.0%)
# abacus-Multicolored     : 3/10 (30.0%)
# abacus-Orange           : 0/10 (0.0%)
# jack-o-lantern-Orange   : 0/10 (0.0%)
# jack-o-lantern-Multicolored: 2/10 (20.0%)
# jack-o-lantern-Yellow   : 10/10 (100.0%)
# camcorder-Grey          : 6/10 (60.0%)
# camcorder-Multicolored  : 1/10 (10.0%)
# camcorder-Blue          : 10/10 (100.0%)
# bird-White              : 10/10 (100.0%)
# bird-Multicolored       : 1/10 (10.0%)
# bird-Grey               : 8/10 (80.0%)
# bird-Orange             : 10/10 (100.0%)
# saddle-Multicolored     : 2/10 (20.0%)
# saddle-Yellow           : 10/10 (100.0%)
# saddle-Brown            : 0/10 (0.0%)
# saddle-Orange           : 5/10 (50.0%)
# saddle-Grey             : 6/10 (60.0%)
# saddle-Red              : 10/10 (100.0%)
# handbag-Multicolored    : 6/10 (60.0%)
# handbag-Blue            : 0/10 (0.0%)
# handbag-Yellow          : 1/10 (10.0%)
# handbag-Orange          : 10/10 (100.0%)
# handbag-Red             : 10/10 (100.0%)
# handbag-Grey            : 10/10 (100.0%)
# stool-Yellow            : 10/10 (100.0%)
# stool-Grey              : 4/10 (40.0%)
# stool-Multicolored      : 3/10 (30.0%)
# stool-Orange            : 10/10 (100.0%)
# toyrabbit-Multicolored  : 2/10 (20.0%)
# toyrabbit-White         : 10/10 (100.0%)
# toyrabbit-Grey          : 0/10 (0.0%)
# candleholderwithcandle-Multicolored: 0/10 (0.0%)
# candleholderwithcandle-Yellow: 10/10 (100.0%)
# candleholderwithcandle-Orange: 10/10 (100.0%)
# cushion-Multicolored    : 1/10 (10.0%)
# cushion-Orange          : 10/10 (100.0%)
# cushion-Red             : 3/10 (30.0%)
# cushion-Grey            : 10/10 (100.0%)
# cushion-Blue            : 10/10 (100.0%)
# lock-Orange             : 10/10 (100.0%)
# lock-Multicolored       : 2/10 (20.0%)
# lock-Yellow             : 10/10 (100.0%)
# lock-Grey               : 1/10 (10.0%)
# train-Blue              : 10/10 (100.0%)
# train-Orange            : 10/10 (100.0%)
# ring-Grey               : 6/10 (60.0%)
# ring-Multicolored       : 1/10 (10.0%)
# ring-Yellow             : 3/10 (30.0%)
# goggle-Multicolored     : 6/10 (60.0%)
# goggle-Grey             : 9/10 (90.0%)
# goggle-Yellow           : 10/10 (100.0%)
# goggle-Blue             : 10/10 (100.0%)
# trumpet-Grey            : 2/10 (20.0%)
# trumpet-Green           : 10/10 (100.0%)
# trumpet-Yellow          : 5/10 (50.0%)
# trumpet-Orange          : 10/10 (100.0%)
# trumpet-Red             : 10/10 (100.0%)
# vase-Multicolored       : 6/10 (60.0%)
# vase-Green              : 10/10 (100.0%)
# vase-Grey               : 10/10 (100.0%)
# vase-Yellow             : 4/10 (40.0%)
# vase-Orange             : 0/10 (0.0%)
# axe-Multicolored        : 4/10 (40.0%)
# axe-Orange              : 9/10 (90.0%)
# axe-Grey                : 7/10 (70.0%)
# axe-Red                 : 10/10 (100.0%)
# tricycle-Multicolored   : 2/10 (20.0%)
# tricycle-Red            : 2/10 (20.0%)
# tricycle-Blue           : 5/10 (50.0%)
# tricycle-Grey           : 10/10 (100.0%)
# toothpaste-Multicolored : 5/10 (50.0%)
# toothpaste-Green        : 2/10 (20.0%)
# toothpaste-Red          : 1/10 (10.0%)
# toothpaste-Grey         : 10/10 (100.0%)
# nailpolish-Purple       : 3/10 (30.0%)
# nailpolish-Brown        : 10/10 (100.0%)
# nailpolish-Blue         : 10/10 (100.0%)
# nailpolish-Grey         : 10/10 (100.0%)
# nailpolish-Pink         : 9/10 (90.0%)
# nailpolish-Multicolored : 10/10 (100.0%)
# nailpolish-Red          : 1/10 (10.0%)
# nailpolish-Yellow       : 10/10 (100.0%)
# nailpolish-Green        : 10/10 (100.0%)
# calculator-Multicolored : 5/10 (50.0%)
# calculator-Grey         : 3/10 (30.0%)
# calculator-Purple       : 10/10 (100.0%)
# pen-Blue                : 9/10 (90.0%)
# pen-Grey                : 10/10 (100.0%)
# pen-Multicolored        : 3/10 (30.0%)
# pen-Pink                : 10/10 (100.0%)
# tree-Yellow             : 10/10 (100.0%)
# tree-Green              : 10/10 (100.0%)
# earings-Multicolored    : 4/10 (40.0%)
# earings-Yellow          : 5/10 (50.0%)
# earings-Grey            : 4/10 (40.0%)
# earings-Green           : 10/10 (100.0%)
# toyhorse-Brown          : 0/10 (0.0%)
# toyhorse-Orange         : 7/10 (70.0%)
# toyhorse-Yellow         : 10/10 (100.0%)
# toyhorse-Multicolored   : 5/10 (50.0%)
# toyhorse-Grey           : 5/10 (50.0%)
# gamehandheld-Multicolored: 7/10 (70.0%)
# gamehandheld-Grey       : 0/10 (0.0%)
# gamehandheld-Pink       : 10/10 (100.0%)
# gamehandheld-Black      : 10/10 (100.0%)
# apple-Multicolored      : 3/10 (30.0%)
# apple-Red               : 2/10 (20.0%)
# apple-Green             : 10/10 (100.0%)
# apple-Yellow            : 10/10 (100.0%)
# apple-Orange            : 5/10 (50.0%)
# saltpeppershake-Multicolored: 1/10 (10.0%)
# saltpeppershake-Yellow  : 0/10 (0.0%)
# saltpeppershake-Grey    : 10/10 (100.0%)
# saltpeppershake-Brown   : 10/10 (100.0%)
# dresser-Brown           : 8/10 (80.0%)
# dresser-Orange          : 0/10 (0.0%)
# dresser-Red             : 10/10 (100.0%)
# rug-Yellow              : 10/10 (100.0%)
# rug-Multicolored        : 4/10 (40.0%)
# rug-Orange              : 3/10 (30.0%)
# wineglass-Grey          : 8/10 (80.0%)
# wineglass-Blue          : 9/10 (90.0%)
# wineglass-Green         : 10/10 (100.0%)
# wineglass-Multicolored  : 10/10 (100.0%)
# breadloaf-Brown         : 10/10 (100.0%)
# breadloaf-Multicolored  : 0/10 (0.0%)
# breadloaf-Orange        : 2/10 (20.0%)
# breadloaf-Yellow        : 0/10 (0.0%)
# keyboard-Multicolored   : 0/10 (0.0%)
# keyboard-Grey           : 2/10 (20.0%)
# keyboard-Black          : 10/10 (100.0%)
# keyboard-Blue           : 10/10 (100.0%)
# meat-Red                : 4/10 (40.0%)
# meat-Multicolored       : 1/10 (10.0%)
# meat-Orange             : 5/10 (50.0%)
# meat-Pink               : 10/10 (100.0%)
# sippycup-Multicolored   : 0/10 (0.0%)
# sippycup-Blue           : 10/10 (100.0%)
# sippycup-Green          : 10/10 (100.0%)
# cookie-Yellow           : 5/10 (50.0%)
# cookie-Multicolored     : 1/10 (10.0%)
# cookie-Brown            : 10/10 (100.0%)
# cookie-Orange           : 10/10 (100.0%)
# helmet-Red              : 10/10 (100.0%)
# helmet-Blue             : 3/10 (30.0%)
# helmet-Grey             : 10/10 (100.0%)
# helmet-Purple           : 10/10 (100.0%)
# helmet-Multicolored     : 3/10 (30.0%)
# helmet-White            : 10/10 (100.0%)
# helmet-Black            : 1/10 (10.0%)
# doll-Multicolored       : 4/10 (40.0%)
# doll-Pink               : 10/10 (100.0%)
# doll-Red                : 1/10 (10.0%)
# doll-Black              : 10/10 (100.0%)
# doll-White              : 10/10 (100.0%)
# doll-Blue               : 10/10 (100.0%)
# pipe-Black              : 5/10 (50.0%)
# pipe-Brown              : 0/10 (0.0%)
# pipe-Multicolored       : 4/10 (40.0%)
# pipe-Yellow             : 10/10 (100.0%)
# christmastreeornamantball-Multicolored: 3/10 (30.0%)
# christmastreeornamantball-Pink: 10/10 (100.0%)
# christmastreeornamantball-Brown: 10/10 (100.0%)
# christmastreeornamantball-Orange: 10/10 (100.0%)
# christmastreeornamantball-Green: 10/10 (100.0%)
# christmastreeornamantball-Red: 10/10 (100.0%)
# telescope-Multicolored  : 3/10 (30.0%)
# telescope-Grey          : 0/10 (0.0%)
# telescope-Black         : 6/10 (60.0%)
# suitcase-Multicolored   : 0/10 (0.0%)
# suitcase-Blue           : 9/10 (90.0%)
# suitcase-Brown          : 6/10 (60.0%)
# suitcase-Black          : 10/10 (100.0%)
# suitcase-Orange         : 10/10 (100.0%)
# suitcase-Pink           : 10/10 (100.0%)
# suitcase-Red            : 10/10 (100.0%)
#
# CLIP Overall Accuracy: 62.1%
