# %% [markdown]
# # Different Class Different Size (DCDS) Comparison
#
# This notebook compares CVCL and CLIP models on prototype evaluation where distractors differ in class AND size.
# For example, testing a large apple against small car, medium ball, tiny book.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------------------------------- - 12.3/12.8 MB 70.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 66.7 MB/s  0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os
import sys
import random
import torch
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from collections import defaultdict

# Path setup
REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir, os.pardir, os.pardir))

# Add discover-hidden-visual-concepts to path
DISCOVER_ROOT = os.path.join(REPO_ROOT, 'discover-hidden-visual-concepts')
sys.path.insert(0, DISCOVER_ROOT)
sys.path.insert(0, REPO_ROOT)

# Import from discover-hidden-visual-concepts repo
sys.path.append(os.path.join(DISCOVER_ROOT, 'src'))
from utils.model_loader import load_model
from models.feature_extractor import FeatureExtractor
from models.multimodal.multimodal_lit import MultiModalLitModel

# hard-coded paths
CSV_PATH = os.path.join(REPO_ROOT, 'data', 'KonkLab', 'testdata.csv')
IMG_DIR = os.path.join(REPO_ROOT, 'data', 'KonkLab', '17-objects')
MASTER_CSV = os.path.join(REPO_ROOT, 'PatrickProject', 'Chart_Generation', 'all_prototype_results.csv')
# Out:
# c:\Users\jbats\miniconda3\envs\ntu-synthetic\lib\site-packages\clip\clip.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import packaging

# %%
# Shared Dataset and Helper Functions
class SizeImageDataset(Dataset):
    """Dataset returning (img_tensor, class, size, idx)."""
    def __init__(self, csv_path, img_dir, transform):
        self.df = pd.read_csv(csv_path)
        required = ['Filename','Class','Size']
        assert all(c in self.df for c in required), f"CSV must contain columns: {required}"
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        cls, sz = row['Class'], row['Size']
        fn = row['Filename']
        path = os.path.join(self.img_dir, cls, fn)
        img = Image.open(path).convert('RGB')
        return self.transform(img), cls, sz, idx

def collate_fn(batch):
    imgs = torch.stack([b[0] for b in batch])
    classes = [b[1] for b in batch]
    sizes = [b[2] for b in batch]
    idxs = [b[3] for b in batch]
    return imgs, classes, sizes, idxs

def run_dcds_test(model_name, seed=0, device='cuda' if torch.cuda.is_available() else 'cpu', batch_size=64, trials_per_tuple=10, max_images=None):
    """Run Different Class Different Size (DCDS) evaluation.
    
    Tests if model can identify objects when distractors differ in BOTH attributes:
    - Different class
    - Different size
    
    This should be an easier test as distractors are quite different from the query.
    Example: large apple vs. small car, medium ball, tiny book
    """
    random.seed(seed)
    torch.manual_seed(seed)

    # 1) load model & transform
    model, transform = load_model(model_name, seed=seed, device=device)
    extractor = FeatureExtractor(model_name, model, device)
    print(f"[INFO] Loaded model '{model_name}'")

    # 2) prepare DataLoader & extract embeddings
    ds = SizeImageDataset(CSV_PATH, IMG_DIR, transform)
    loader = DataLoader(ds, batch_size=batch_size, shuffle=False, num_workers=0, collate_fn=collate_fn)

    all_embs, all_classes, all_sizes, all_idxs = [], [], [], []
    with torch.no_grad():
        for imgs, classes, sizes, idxs in loader:
            feats = extractor.get_img_feature(imgs.to(device))
            feats = extractor.norm_features(feats).cpu()
            feats = feats.float()
            all_embs.append(feats)
            all_classes.extend(classes)
            all_sizes.extend(sizes)
            all_idxs.extend(idxs)
    all_embs = torch.cat(all_embs, dim=0)
    print(f"[INFO] Extracted embeddings for {len(all_idxs)} images")

    # 3) group by (class, size) pair
    cs_idxs = defaultdict(lambda: defaultdict(list))
    for idx, cls, sz in zip(all_idxs, all_classes, all_sizes):
        cs_idxs[cls][sz].append(idx)

    # 4) run evaluation
    total_correct = 0
    total_trials = 0
    tuple_results = {}
    
    print("[INFO] Running 4-way trials: distractors with different class AND different size")
    for cls, size_groups in cs_idxs.items():
        for size, idx_list in size_groups.items():
            # Get pool: different class AND different size
            distractor_pool = [
                i for i, c, s in zip(all_idxs, all_classes, all_sizes)
                if c != cls and s != size
            ]
            
            if len(idx_list) < 1 or len(distractor_pool) < 3:
                continue

            correct = 0
            for _ in range(trials_per_tuple):
                q = random.choice(idx_list)
                same_rest = [i for i in idx_list if i != q]
                if same_rest:
                    proto = all_embs[[all_idxs.index(i) for i in same_rest]].mean(0)
                else:
                    proto = all_embs[all_idxs.index(q)]
                proto = proto / proto.norm()

                distractors = random.sample(distractor_pool, 3)
                candidates = [q] + distractors
                feats_cand = all_embs[[all_idxs.index(i) for i in candidates]]
                sims = feats_cand @ proto
                guess = candidates[sims.argmax().item()]

                correct += int(guess == q)
                total_correct += int(guess == q)
                total_trials += 1

            acc = correct / trials_per_tuple
            key = f"{cls}-{size}"
            tuple_results[key] = {'correct': correct, 'trials': trials_per_tuple, 'accuracy': acc}
            print(f"{cls:12s} / {size:6s} : {correct}/{trials_per_tuple} ({acc:.1%})")

    overall_acc = total_correct / total_trials if total_trials else 0.0
    print(f"\n[OK] Overall accuracy: {total_correct}/{total_trials} ({overall_acc:.1%})")
    
    # 5) save results
    summary_df = pd.DataFrame([{'Model': model_name, 'Test': 'Different-Class-Different-Size', 'Correct': total_correct, 'Trials': total_trials, 'Accuracy': overall_acc}])
    
    os.makedirs(os.path.dirname(MASTER_CSV), exist_ok=True)
    if os.path.exists(MASTER_CSV):
        summary_df.to_csv(MASTER_CSV, mode='a', header=False, index=False, float_format='%.4f')
    else:
        summary_df.to_csv(MASTER_CSV, index=False, float_format='%.4f')

    return tuple_results, overall_acc

# %% [markdown]
# ## CVCL Test

# %%
# Run CVCL evaluation
cvcl_results, cvcl_overall = run_dcds_test('cvcl-resnext')

print("\nCVCL Results by Class-Size:")
for key, res in cvcl_results.items():
    print(f"{key:25s}: {res['correct']}/{res['trials']} ({res['accuracy']:.1%})")
print(f"\nCVCL Overall Accuracy: {cvcl_overall:.1%}")
# Out:
# Loading checkpoint from C:\Users\jbats\.cache\huggingface\hub\models--wkvong--cvcl_s_dino_resnext50_embedding\snapshots\f50eaa0c50a6076a5190b1dd52aeeb6c3e747045\cvcl_s_dino_resnext50_embedding.ckpt
# Lightning automatically upgraded your loaded checkpoint from v1.5.8 to v2.5.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\jbats\.cache\huggingface\hub\models--wkvong--cvcl_s_dino_resnext50_embedding\snapshots\f50eaa0c50a6076a5190b1dd52aeeb6c3e747045\cvcl_s_dino_resnext50_embedding.ckpt`
# [INFO] Loaded model 'cvcl-resnext'
# [INFO] Extracted embeddings for 1005 images
# [INFO] Running 4-way trials: distractors with different class AND different size
# butterfly    / Medium : 9/10 (90.0%)
# muffins      / Medium : 10/10 (100.0%)
# muffins      / Large  : 10/10 (100.0%)
# pitcher      / Medium : 9/10 (90.0%)
# pitcher      / Large  : 10/10 (100.0%)
# tennisracquet / Small  : 10/10 (100.0%)
# tennisracquet / Medium : 10/10 (100.0%)
# phone        / Medium : 10/10 (100.0%)
# phone        / Large  : 10/10 (100.0%)
# phone        / Small  : 10/10 (100.0%)
# headband     / Medium : 8/10 (80.0%)
# headband     / Small  : 9/10 (90.0%)
# bagel        / Large  : 10/10 (100.0%)
# bagel        / Medium : 9/10 (90.0%)
# grill        / Medium : 10/10 (100.0%)
# grill        / Small  : 10/10 (100.0%)
# basket       / Medium : 10/10 (100.0%)
# basket       / Small  : 9/10 (90.0%)
# bell         / Small  : 10/10 (100.0%)
# bell         / Medium : 0/10 (0.0%)
# sodacan      / Medium : 10/10 (100.0%)
# microwave    / Medium : 10/10 (100.0%)
# microwave    / Large  : 10/10 (100.0%)
# trophy       / Small  : 10/10 (100.0%)
# trophy       / Medium : 6/10 (60.0%)
# fan          / Medium : 10/10 (100.0%)
# fan          / Small  : 10/10 (100.0%)
# fan          / Large  : 10/10 (100.0%)
# lei          / Medium : 10/10 (100.0%)
# lei          / Small  : 9/10 (90.0%)
# stapler      / Medium : 8/10 (80.0%)
# stapler      / Small  : 10/10 (100.0%)
# exercise_equipment / Small  : 10/10 (100.0%)
# exercise_equipment / Medium : 8/10 (80.0%)
# handgun      / Small  : 10/10 (100.0%)
# handgun      / Medium : 10/10 (100.0%)
# seashell     / Medium : 8/10 (80.0%)
# seashell     / Small  : 10/10 (100.0%)
# powerstrip   / Medium : 10/10 (100.0%)
# powerstrip   / Small  : 7/10 (70.0%)
# lipstick     / Small  : 10/10 (100.0%)
# lipstick     / Medium : 10/10 (100.0%)
# lantern      / Small  : 10/10 (100.0%)
# lantern      / Medium : 10/10 (100.0%)
# doorknob     / Large  : 10/10 (100.0%)
# doorknob     / Medium : 8/10 (80.0%)
# doorknob     / Small  : 10/10 (100.0%)
# abacus       / Small  : 10/10 (100.0%)
# abacus       / Medium : 7/10 (70.0%)
# abacus       / Large  : 10/10 (100.0%)
# jack-o-lantern / Large  : 10/10 (100.0%)
# jack-o-lantern / Medium : 10/10 (100.0%)
# camcorder    / Medium : 9/10 (90.0%)
# bird         / Medium : 8/10 (80.0%)
# bird         / Small  : 10/10 (100.0%)
# saddle       / Medium : 9/10 (90.0%)
# saddle       / Small  : 10/10 (100.0%)
# handbag      / Medium : 8/10 (80.0%)
# handbag      / Small  : 10/10 (100.0%)
# handbag      / Large  : 10/10 (100.0%)
# stool        / Medium : 4/10 (40.0%)
# stool        / Small  : 10/10 (100.0%)
# toyrabbit    / Medium : 10/10 (100.0%)
# toyrabbit    / Small  : 5/10 (50.0%)
# candleholderwithcandle / Small  : 10/10 (100.0%)
# candleholderwithcandle / Medium : 10/10 (100.0%)
# cushion      / Large  : 7/10 (70.0%)
# lock         / Medium : 10/10 (100.0%)
# lock         / Small  : 10/10 (100.0%)
# lock         / Large  : 10/10 (100.0%)
# train        / Medium : 9/10 (90.0%)
# train        / Small  : 10/10 (100.0%)
# bonzai       / Medium : 10/10 (100.0%)
# bonzai       / Small  : 9/10 (90.0%)
# ring         / Medium : 10/10 (100.0%)
# ring         / Small  : 10/10 (100.0%)
# goggle       / Small  : 9/10 (90.0%)
# goggle       / Medium : 10/10 (100.0%)
# trumpet      / Small  : 9/10 (90.0%)
# trumpet      / Medium : 8/10 (80.0%)
# vase         / Medium : 3/10 (30.0%)
# vase         / Small  : 0/10 (0.0%)
# axe          / Small  : 10/10 (100.0%)
# tricycle     / Small  : 10/10 (100.0%)
# tricycle     / Medium : 10/10 (100.0%)
# toothpaste   / Small  : 10/10 (100.0%)
# toothpaste   / Medium : 10/10 (100.0%)
# nailpolish   / Medium : 10/10 (100.0%)
# nailpolish   / Small  : 10/10 (100.0%)
# calculator   / Medium : 10/10 (100.0%)
# calculator   / Large  : 9/10 (90.0%)
# pen          / Small  : 10/10 (100.0%)
# tree         / Medium : 10/10 (100.0%)
# tree         / Small  : 10/10 (100.0%)
# earings      / Small  : 10/10 (100.0%)
# earings      / Medium : 7/10 (70.0%)
# toyhorse     / Medium : 10/10 (100.0%)
# toyhorse     / Small  : 10/10 (100.0%)
# gamehandheld / Medium : 10/10 (100.0%)
# apple        / Large  : 10/10 (100.0%)
# apple        / Medium : 10/10 (100.0%)
# babushkadolls / Medium : 10/10 (100.0%)
# babushkadolls / Small  : 10/10 (100.0%)
# saltpeppershake / Medium : 9/10 (90.0%)
# saltpeppershake / Large  : 10/10 (100.0%)
# dresser      / Medium : 10/10 (100.0%)
# dresser      / Large  : 10/10 (100.0%)
# rug          / Medium : 10/10 (100.0%)
# rug          / Large  : 10/10 (100.0%)
# wineglass    / Small  : 10/10 (100.0%)
# wineglass    / Medium : 10/10 (100.0%)
# breadloaf    / Medium : 8/10 (80.0%)
# breadloaf    / Small  : 10/10 (100.0%)
# keyboard     / Medium : 10/10 (100.0%)
# keyboard     / Small  : 9/10 (90.0%)
# meat         / Medium : 10/10 (100.0%)
# meat         / Large  : 9/10 (90.0%)
# sippycup     / Medium : 10/10 (100.0%)
# cookie       / Large  : 9/10 (90.0%)
# cookie       / Medium : 8/10 (80.0%)
# helmet       / Medium : 10/10 (100.0%)
# doll         / Medium : 9/10 (90.0%)
# doll         / Small  : 10/10 (100.0%)
# pipe         / Small  : 10/10 (100.0%)
# pipe         / Medium : 10/10 (100.0%)
# christmastreeornamantball / Medium : 9/10 (90.0%)
# telescope    / Small  : 10/10 (100.0%)
# telescope    / Medium : 10/10 (100.0%)
# suitcase     / Medium : 9/10 (90.0%)
#
# [OK] Overall accuracy: 1196/1290 (92.7%)
#
# CVCL Results by Class-Size:
# butterfly-Medium         : 9/10 (90.0%)
# muffins-Medium           : 10/10 (100.0%)
# muffins-Large            : 10/10 (100.0%)
# pitcher-Medium           : 9/10 (90.0%)
# pitcher-Large            : 10/10 (100.0%)
# tennisracquet-Small      : 10/10 (100.0%)
# tennisracquet-Medium     : 10/10 (100.0%)
# phone-Medium             : 10/10 (100.0%)
# phone-Large              : 10/10 (100.0%)
# phone-Small              : 10/10 (100.0%)
# headband-Medium          : 8/10 (80.0%)
# headband-Small           : 9/10 (90.0%)
# bagel-Large              : 10/10 (100.0%)
# bagel-Medium             : 9/10 (90.0%)
# grill-Medium             : 10/10 (100.0%)
# grill-Small              : 10/10 (100.0%)
# basket-Medium            : 10/10 (100.0%)
# basket-Small             : 9/10 (90.0%)
# bell-Small               : 10/10 (100.0%)
# bell-Medium              : 0/10 (0.0%)
# sodacan-Medium           : 10/10 (100.0%)
# microwave-Medium         : 10/10 (100.0%)
# microwave-Large          : 10/10 (100.0%)
# trophy-Small             : 10/10 (100.0%)
# trophy-Medium            : 6/10 (60.0%)
# fan-Medium               : 10/10 (100.0%)
# fan-Small                : 10/10 (100.0%)
# fan-Large                : 10/10 (100.0%)
# lei-Medium               : 10/10 (100.0%)
# lei-Small                : 9/10 (90.0%)
# stapler-Medium           : 8/10 (80.0%)
# stapler-Small            : 10/10 (100.0%)
# exercise_equipment-Small : 10/10 (100.0%)
# exercise_equipment-Medium: 8/10 (80.0%)
# handgun-Small            : 10/10 (100.0%)
# handgun-Medium           : 10/10 (100.0%)
# seashell-Medium          : 8/10 (80.0%)
# seashell-Small           : 10/10 (100.0%)
# powerstrip-Medium        : 10/10 (100.0%)
# powerstrip-Small         : 7/10 (70.0%)
# lipstick-Small           : 10/10 (100.0%)
# lipstick-Medium          : 10/10 (100.0%)
# lantern-Small            : 10/10 (100.0%)
# lantern-Medium           : 10/10 (100.0%)
# doorknob-Large           : 10/10 (100.0%)
# doorknob-Medium          : 8/10 (80.0%)
# doorknob-Small           : 10/10 (100.0%)
# abacus-Small             : 10/10 (100.0%)
# abacus-Medium            : 7/10 (70.0%)
# abacus-Large             : 10/10 (100.0%)
# jack-o-lantern-Large     : 10/10 (100.0%)
# jack-o-lantern-Medium    : 10/10 (100.0%)
# camcorder-Medium         : 9/10 (90.0%)
# bird-Medium              : 8/10 (80.0%)
# bird-Small               : 10/10 (100.0%)
# saddle-Medium            : 9/10 (90.0%)
# saddle-Small             : 10/10 (100.0%)
# handbag-Medium           : 8/10 (80.0%)
# handbag-Small            : 10/10 (100.0%)
# handbag-Large            : 10/10 (100.0%)
# stool-Medium             : 4/10 (40.0%)
# stool-Small              : 10/10 (100.0%)
# toyrabbit-Medium         : 10/10 (100.0%)
# toyrabbit-Small          : 5/10 (50.0%)
# candleholderwithcandle-Small: 10/10 (100.0%)
# candleholderwithcandle-Medium: 10/10 (100.0%)
# cushion-Large            : 7/10 (70.0%)
# lock-Medium              : 10/10 (100.0%)
# lock-Small               : 10/10 (100.0%)
# lock-Large               : 10/10 (100.0%)
# train-Medium             : 9/10 (90.0%)
# train-Small              : 10/10 (100.0%)
# bonzai-Medium            : 10/10 (100.0%)
# bonzai-Small             : 9/10 (90.0%)
# ring-Medium              : 10/10 (100.0%)
# ring-Small               : 10/10 (100.0%)
# goggle-Small             : 9/10 (90.0%)
# goggle-Medium            : 10/10 (100.0%)
# trumpet-Small            : 9/10 (90.0%)
# trumpet-Medium           : 8/10 (80.0%)
# vase-Medium              : 3/10 (30.0%)
# vase-Small               : 0/10 (0.0%)
# axe-Small                : 10/10 (100.0%)
# tricycle-Small           : 10/10 (100.0%)
# tricycle-Medium          : 10/10 (100.0%)
# toothpaste-Small         : 10/10 (100.0%)
# toothpaste-Medium        : 10/10 (100.0%)
# nailpolish-Medium        : 10/10 (100.0%)
# nailpolish-Small         : 10/10 (100.0%)
# calculator-Medium        : 10/10 (100.0%)
# calculator-Large         : 9/10 (90.0%)
# pen-Small                : 10/10 (100.0%)
# tree-Medium              : 10/10 (100.0%)
# tree-Small               : 10/10 (100.0%)
# earings-Small            : 10/10 (100.0%)
# earings-Medium           : 7/10 (70.0%)
# toyhorse-Medium          : 10/10 (100.0%)
# toyhorse-Small           : 10/10 (100.0%)
# gamehandheld-Medium      : 10/10 (100.0%)
# apple-Large              : 10/10 (100.0%)
# apple-Medium             : 10/10 (100.0%)
# babushkadolls-Medium     : 10/10 (100.0%)
# babushkadolls-Small      : 10/10 (100.0%)
# saltpeppershake-Medium   : 9/10 (90.0%)
# saltpeppershake-Large    : 10/10 (100.0%)
# dresser-Medium           : 10/10 (100.0%)
# dresser-Large            : 10/10 (100.0%)
# rug-Medium               : 10/10 (100.0%)
# rug-Large                : 10/10 (100.0%)
# wineglass-Small          : 10/10 (100.0%)
# wineglass-Medium         : 10/10 (100.0%)
# breadloaf-Medium         : 8/10 (80.0%)
# breadloaf-Small          : 10/10 (100.0%)
# keyboard-Medium          : 10/10 (100.0%)
# keyboard-Small           : 9/10 (90.0%)
# meat-Medium              : 10/10 (100.0%)
# meat-Large               : 9/10 (90.0%)
# sippycup-Medium          : 10/10 (100.0%)
# cookie-Large             : 9/10 (90.0%)
# cookie-Medium            : 8/10 (80.0%)
# helmet-Medium            : 10/10 (100.0%)
# doll-Medium              : 9/10 (90.0%)
# doll-Small               : 10/10 (100.0%)
# pipe-Small               : 10/10 (100.0%)
# pipe-Medium              : 10/10 (100.0%)
# christmastreeornamantball-Medium: 9/10 (90.0%)
# telescope-Small          : 10/10 (100.0%)
# telescope-Medium         : 10/10 (100.0%)
# suitcase-Medium          : 9/10 (90.0%)
#
# CVCL Overall Accuracy: 92.7%

# %% [markdown]
# ## CLIP Test

# %%
# Run CLIP evaluation
clip_results, clip_overall = run_dcds_test('clip-resnext')

print("\nCLIP Results by Class-Size:")
for key, res in clip_results.items():
    print(f"{key:25s}: {res['correct']}/{res['trials']} ({res['accuracy']:.1%})")
print(f"\nCLIP Overall Accuracy: {clip_overall:.1%}")
# Out:
# [INFO] Loaded model 'clip-resnext'
# c:\Users\jbats\miniconda3\envs\ntu-synthetic\lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# [INFO] Extracted embeddings for 1005 images
# [INFO] Running 4-way trials: distractors with different class AND different size
# butterfly    / Medium : 10/10 (100.0%)
# muffins      / Medium : 10/10 (100.0%)
# muffins      / Large  : 10/10 (100.0%)
# pitcher      / Medium : 10/10 (100.0%)
# pitcher      / Large  : 10/10 (100.0%)
# tennisracquet / Small  : 10/10 (100.0%)
# tennisracquet / Medium : 10/10 (100.0%)
# phone        / Medium : 10/10 (100.0%)
# phone        / Large  : 10/10 (100.0%)
# phone        / Small  : 10/10 (100.0%)
# headband     / Medium : 9/10 (90.0%)
# headband     / Small  : 10/10 (100.0%)
# bagel        / Large  : 10/10 (100.0%)
# bagel        / Medium : 10/10 (100.0%)
# grill        / Medium : 10/10 (100.0%)
# grill        / Small  : 10/10 (100.0%)
# basket       / Medium : 10/10 (100.0%)
# basket       / Small  : 10/10 (100.0%)
# bell         / Small  : 9/10 (90.0%)
# bell         / Medium : 4/10 (40.0%)
# sodacan      / Medium : 10/10 (100.0%)
# microwave    / Medium : 10/10 (100.0%)
# microwave    / Large  : 10/10 (100.0%)
# trophy       / Small  : 10/10 (100.0%)
# trophy       / Medium : 10/10 (100.0%)
# fan          / Medium : 10/10 (100.0%)
# fan          / Small  : 10/10 (100.0%)
# fan          / Large  : 10/10 (100.0%)
# lei          / Medium : 10/10 (100.0%)
# lei          / Small  : 10/10 (100.0%)
# stapler      / Medium : 9/10 (90.0%)
# stapler      / Small  : 10/10 (100.0%)
# exercise_equipment / Small  : 10/10 (100.0%)
# exercise_equipment / Medium : 10/10 (100.0%)
# handgun      / Small  : 10/10 (100.0%)
# handgun      / Medium : 10/10 (100.0%)
# seashell     / Medium : 10/10 (100.0%)
# seashell     / Small  : 10/10 (100.0%)
# powerstrip   / Medium : 10/10 (100.0%)
# powerstrip   / Small  : 10/10 (100.0%)
# lipstick     / Small  : 10/10 (100.0%)
# lipstick     / Medium : 10/10 (100.0%)
# lantern      / Small  : 10/10 (100.0%)
# lantern      / Medium : 10/10 (100.0%)
# doorknob     / Large  : 10/10 (100.0%)
# doorknob     / Medium : 10/10 (100.0%)
# doorknob     / Small  : 10/10 (100.0%)
# abacus       / Small  : 10/10 (100.0%)
# abacus       / Medium : 10/10 (100.0%)
# abacus       / Large  : 10/10 (100.0%)
# jack-o-lantern / Large  : 10/10 (100.0%)
# jack-o-lantern / Medium : 10/10 (100.0%)
# camcorder    / Medium : 10/10 (100.0%)
# bird         / Medium : 10/10 (100.0%)
# bird         / Small  : 10/10 (100.0%)
# saddle       / Medium : 10/10 (100.0%)
# saddle       / Small  : 10/10 (100.0%)
# handbag      / Medium : 9/10 (90.0%)
# handbag      / Small  : 10/10 (100.0%)
# handbag      / Large  : 10/10 (100.0%)
# stool        / Medium : 10/10 (100.0%)
# stool        / Small  : 10/10 (100.0%)
# toyrabbit    / Medium : 10/10 (100.0%)
# toyrabbit    / Small  : 10/10 (100.0%)
# candleholderwithcandle / Small  : 10/10 (100.0%)
# candleholderwithcandle / Medium : 10/10 (100.0%)
# cushion      / Large  : 10/10 (100.0%)
# lock         / Medium : 10/10 (100.0%)
# lock         / Small  : 10/10 (100.0%)
# lock         / Large  : 10/10 (100.0%)
# train        / Medium : 10/10 (100.0%)
# train        / Small  : 10/10 (100.0%)
# bonzai       / Medium : 10/10 (100.0%)
# bonzai       / Small  : 10/10 (100.0%)
# ring         / Medium : 9/10 (90.0%)
# ring         / Small  : 10/10 (100.0%)
# goggle       / Small  : 10/10 (100.0%)
# goggle       / Medium : 10/10 (100.0%)
# trumpet      / Small  : 10/10 (100.0%)
# trumpet      / Medium : 10/10 (100.0%)
# vase         / Medium : 9/10 (90.0%)
# vase         / Small  : 8/10 (80.0%)
# axe          / Small  : 10/10 (100.0%)
# tricycle     / Small  : 10/10 (100.0%)
# tricycle     / Medium : 10/10 (100.0%)
# toothpaste   / Small  : 10/10 (100.0%)
# toothpaste   / Medium : 10/10 (100.0%)
# nailpolish   / Medium : 10/10 (100.0%)
# nailpolish   / Small  : 10/10 (100.0%)
# calculator   / Medium : 10/10 (100.0%)
# calculator   / Large  : 10/10 (100.0%)
# pen          / Small  : 10/10 (100.0%)
# tree         / Medium : 10/10 (100.0%)
# tree         / Small  : 10/10 (100.0%)
# earings      / Small  : 10/10 (100.0%)
# earings      / Medium : 10/10 (100.0%)
# toyhorse     / Medium : 10/10 (100.0%)
# toyhorse     / Small  : 10/10 (100.0%)
# gamehandheld / Medium : 10/10 (100.0%)
# apple        / Large  : 10/10 (100.0%)
# apple        / Medium : 10/10 (100.0%)
# babushkadolls / Medium : 10/10 (100.0%)
# babushkadolls / Small  : 10/10 (100.0%)
# saltpeppershake / Medium : 10/10 (100.0%)
# saltpeppershake / Large  : 10/10 (100.0%)
# dresser      / Medium : 10/10 (100.0%)
# dresser      / Large  : 10/10 (100.0%)
# rug          / Medium : 10/10 (100.0%)
# rug          / Large  : 10/10 (100.0%)
# wineglass    / Small  : 10/10 (100.0%)
# wineglass    / Medium : 10/10 (100.0%)
# breadloaf    / Medium : 10/10 (100.0%)
# breadloaf    / Small  : 10/10 (100.0%)
# keyboard     / Medium : 10/10 (100.0%)
# keyboard     / Small  : 10/10 (100.0%)
# meat         / Medium : 10/10 (100.0%)
# meat         / Large  : 10/10 (100.0%)
# sippycup     / Medium : 10/10 (100.0%)
# cookie       / Large  : 10/10 (100.0%)
# cookie       / Medium : 10/10 (100.0%)
# helmet       / Medium : 10/10 (100.0%)
# doll         / Medium : 10/10 (100.0%)
# doll         / Small  : 10/10 (100.0%)
# pipe         / Small  : 10/10 (100.0%)
# pipe         / Medium : 10/10 (100.0%)
# christmastreeornamantball / Medium : 10/10 (100.0%)
# telescope    / Small  : 10/10 (100.0%)
# telescope    / Medium : 10/10 (100.0%)
# suitcase     / Medium : 10/10 (100.0%)
#
# [OK] Overall accuracy: 1276/1290 (98.9%)
#
# CLIP Results by Class-Size:
# butterfly-Medium         : 10/10 (100.0%)
# muffins-Medium           : 10/10 (100.0%)
# muffins-Large            : 10/10 (100.0%)
# pitcher-Medium           : 10/10 (100.0%)
# pitcher-Large            : 10/10 (100.0%)
# tennisracquet-Small      : 10/10 (100.0%)
# tennisracquet-Medium     : 10/10 (100.0%)
# phone-Medium             : 10/10 (100.0%)
# phone-Large              : 10/10 (100.0%)
# phone-Small              : 10/10 (100.0%)
# headband-Medium          : 9/10 (90.0%)
# headband-Small           : 10/10 (100.0%)
# bagel-Large              : 10/10 (100.0%)
# bagel-Medium             : 10/10 (100.0%)
# grill-Medium             : 10/10 (100.0%)
# grill-Small              : 10/10 (100.0%)
# basket-Medium            : 10/10 (100.0%)
# basket-Small             : 10/10 (100.0%)
# bell-Small               : 9/10 (90.0%)
# bell-Medium              : 4/10 (40.0%)
# sodacan-Medium           : 10/10 (100.0%)
# microwave-Medium         : 10/10 (100.0%)
# microwave-Large          : 10/10 (100.0%)
# trophy-Small             : 10/10 (100.0%)
# trophy-Medium            : 10/10 (100.0%)
# fan-Medium               : 10/10 (100.0%)
# fan-Small                : 10/10 (100.0%)
# fan-Large                : 10/10 (100.0%)
# lei-Medium               : 10/10 (100.0%)
# lei-Small                : 10/10 (100.0%)
# stapler-Medium           : 9/10 (90.0%)
# stapler-Small            : 10/10 (100.0%)
# exercise_equipment-Small : 10/10 (100.0%)
# exercise_equipment-Medium: 10/10 (100.0%)
# handgun-Small            : 10/10 (100.0%)
# handgun-Medium           : 10/10 (100.0%)
# seashell-Medium          : 10/10 (100.0%)
# seashell-Small           : 10/10 (100.0%)
# powerstrip-Medium        : 10/10 (100.0%)
# powerstrip-Small         : 10/10 (100.0%)
# lipstick-Small           : 10/10 (100.0%)
# lipstick-Medium          : 10/10 (100.0%)
# lantern-Small            : 10/10 (100.0%)
# lantern-Medium           : 10/10 (100.0%)
# doorknob-Large           : 10/10 (100.0%)
# doorknob-Medium          : 10/10 (100.0%)
# doorknob-Small           : 10/10 (100.0%)
# abacus-Small             : 10/10 (100.0%)
# abacus-Medium            : 10/10 (100.0%)
# abacus-Large             : 10/10 (100.0%)
# jack-o-lantern-Large     : 10/10 (100.0%)
# jack-o-lantern-Medium    : 10/10 (100.0%)
# camcorder-Medium         : 10/10 (100.0%)
# bird-Medium              : 10/10 (100.0%)
# bird-Small               : 10/10 (100.0%)
# saddle-Medium            : 10/10 (100.0%)
# saddle-Small             : 10/10 (100.0%)
# handbag-Medium           : 9/10 (90.0%)
# handbag-Small            : 10/10 (100.0%)
# handbag-Large            : 10/10 (100.0%)
# stool-Medium             : 10/10 (100.0%)
# stool-Small              : 10/10 (100.0%)
# toyrabbit-Medium         : 10/10 (100.0%)
# toyrabbit-Small          : 10/10 (100.0%)
# candleholderwithcandle-Small: 10/10 (100.0%)
# candleholderwithcandle-Medium: 10/10 (100.0%)
# cushion-Large            : 10/10 (100.0%)
# lock-Medium              : 10/10 (100.0%)
# lock-Small               : 10/10 (100.0%)
# lock-Large               : 10/10 (100.0%)
# train-Medium             : 10/10 (100.0%)
# train-Small              : 10/10 (100.0%)
# bonzai-Medium            : 10/10 (100.0%)
# bonzai-Small             : 10/10 (100.0%)
# ring-Medium              : 9/10 (90.0%)
# ring-Small               : 10/10 (100.0%)
# goggle-Small             : 10/10 (100.0%)
# goggle-Medium            : 10/10 (100.0%)
# trumpet-Small            : 10/10 (100.0%)
# trumpet-Medium           : 10/10 (100.0%)
# vase-Medium              : 9/10 (90.0%)
# vase-Small               : 8/10 (80.0%)
# axe-Small                : 10/10 (100.0%)
# tricycle-Small           : 10/10 (100.0%)
# tricycle-Medium          : 10/10 (100.0%)
# toothpaste-Small         : 10/10 (100.0%)
# toothpaste-Medium        : 10/10 (100.0%)
# nailpolish-Medium        : 10/10 (100.0%)
# nailpolish-Small         : 10/10 (100.0%)
# calculator-Medium        : 10/10 (100.0%)
# calculator-Large         : 10/10 (100.0%)
# pen-Small                : 10/10 (100.0%)
# tree-Medium              : 10/10 (100.0%)
# tree-Small               : 10/10 (100.0%)
# earings-Small            : 10/10 (100.0%)
# earings-Medium           : 10/10 (100.0%)
# toyhorse-Medium          : 10/10 (100.0%)
# toyhorse-Small           : 10/10 (100.0%)
# gamehandheld-Medium      : 10/10 (100.0%)
# apple-Large              : 10/10 (100.0%)
# apple-Medium             : 10/10 (100.0%)
# babushkadolls-Medium     : 10/10 (100.0%)
# babushkadolls-Small      : 10/10 (100.0%)
# saltpeppershake-Medium   : 10/10 (100.0%)
# saltpeppershake-Large    : 10/10 (100.0%)
# dresser-Medium           : 10/10 (100.0%)
# dresser-Large            : 10/10 (100.0%)
# rug-Medium               : 10/10 (100.0%)
# rug-Large                : 10/10 (100.0%)
# wineglass-Small          : 10/10 (100.0%)
# wineglass-Medium         : 10/10 (100.0%)
# breadloaf-Medium         : 10/10 (100.0%)
# breadloaf-Small          : 10/10 (100.0%)
# keyboard-Medium          : 10/10 (100.0%)
# keyboard-Small           : 10/10 (100.0%)
# meat-Medium              : 10/10 (100.0%)
# meat-Large               : 10/10 (100.0%)
# sippycup-Medium          : 10/10 (100.0%)
# cookie-Large             : 10/10 (100.0%)
# cookie-Medium            : 10/10 (100.0%)
# helmet-Medium            : 10/10 (100.0%)
# doll-Medium              : 10/10 (100.0%)
# doll-Small               : 10/10 (100.0%)
# pipe-Small               : 10/10 (100.0%)
# pipe-Medium              : 10/10 (100.0%)
# christmastreeornamantball-Medium: 10/10 (100.0%)
# telescope-Small          : 10/10 (100.0%)
# telescope-Medium         : 10/10 (100.0%)
# suitcase-Medium          : 10/10 (100.0%)
#
# CLIP Overall Accuracy: 98.9%
